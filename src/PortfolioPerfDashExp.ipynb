# %% [markdown]
# ## Porfilio Performance
#
# Use this notebook to calculate your performance compared to major indices

# %%
import numpy as np
import pandas as pd

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print(f"Current Working Directory: {current_directory}")

# Change the working directory
new_directory = '/mnt/batch/tasks/shared/LS_root/mounts/clusters/spectral-nature/code/Users/omai.r/spectral_nature/src/rh_perf/src'
os.chdir(new_directory)
print(f"Changed Working Directory to: {new_directory}")

# %%
import getpass

import robin_stocks.robinhood as r

def robinhood_login(username, password):
    """
    Logs into Robinhood account using provided username and password.
    
    Parameters:
    username (str): Robinhood account username
    password (str): Robinhood account password
    
    Returns:
    dict: Login result containing access token and other details
    """
    login_result = r.login(username, password)
    return login_result

# Example usage:
# login_result = robinhood_login(rh_username, rh_password)
# print(login_result)
# Prompt for username and password

rh_username = input("Enter your Robinhood username: ")
rh_password = getpass.getpass("Enter your Robinhood password: ")

# Login to Robinhood
login_result = robinhood_login(rh_username, rh_password)
#print(login_result)

# %%
portfolio_data = r.profiles.load_portfolio_profile()
print(portfolio_data)
# Out:
# {'url': 'https://api.robinhood.com/portfolios/641067145/', 'account': 'https://api.robinhood.com/accounts/641067145/', 'start_date': '2019-01-25', 'market_value': '90237.6442', 'equity': '64824.7242', 'extended_hours_market_value': '90383.7287', 'extended_hours_equity': '64970.8087', 'extended_hours_portfolio_equity': '64970.8087', 'last_core_market_value': '90237.6442', 'last_core_equity': '64824.7242', 'last_core_portfolio_equity': '64824.7242', 'excess_margin': '5153.4021', 'excess_maintenance': '19433.0714', 'excess_margin_with_uncleared_deposits': '5153.4021', 'excess_maintenance_with_uncleared_deposits': '19433.0714', 'equity_previous_close': '66216.5200', 'portfolio_equity_previous_close': '66216.5200', 'adjusted_equity_previous_close': '66216.5200', 'adjusted_portfolio_equity_previous_close': '66216.5200', 'withdrawable_amount': '5464.13', 'unwithdrawable_deposits': '0.0000', 'unwithdrawable_grants': '0.0000', 'is_primary_account': True}

# %%
portfolio_data
# Out:
# {'url': 'https://api.robinhood.com/portfolios/641067145/',
#  'account': 'https://api.robinhood.com/accounts/641067145/',
#  'start_date': '2019-01-25',
#  'market_value': '90237.6442',
#  'equity': '64824.7242',
#  'extended_hours_market_value': '90383.7287',
#  'extended_hours_equity': '64970.8087',
#  'extended_hours_portfolio_equity': '64970.8087',
#  'last_core_market_value': '90237.6442',
#  'last_core_equity': '64824.7242',
#  'last_core_portfolio_equity': '64824.7242',
#  'excess_margin': '5153.4021',
#  'excess_maintenance': '19433.0714',
#  'excess_margin_with_uncleared_deposits': '5153.4021',
#  'excess_maintenance_with_uncleared_deposits': '19433.0714',
#  'equity_previous_close': '66216.5200',
#  'portfolio_equity_previous_close': '66216.5200',
#  'adjusted_equity_previous_close': '66216.5200',
#  'adjusted_portfolio_equity_previous_close': '66216.5200',
#  'withdrawable_amount': '5464.13',
#  'unwithdrawable_deposits': '0.0000',
#  'unwithdrawable_grants': '0.0000',
#  'is_primary_account': True}

# %%
holdings_df = r.account.build_holdings(with_dividends=True)

# %%
user_profile = r.account.build_user_profile()

# %%
user_profile
# Out:
# {'equity': '64824.7242',
#  'extended_hours_equity': '64970.8087',
#  'cash': '-25412.92',
#  'dividend_total': 2222.7699999999954}

# %%
historical_df = r.account.get_historical_portfolio(interval='week', span='5year')

# %%
historical_df
# Out:
# {'adjusted_open_equity': None,
#  'adjusted_previous_close_equity': None,
#  'open_equity': None,
#  'previous_close_equity': None,
#  'open_time': None,
#  'interval': 'week',
#  'span': '5year',
#  'bounds': 'regular',
#  'total_return': '6.8994',
#  'equity_historicals': [{'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-01-27T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-02-03T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-02-10T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-02-17T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-02-24T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-03-02T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-03-09T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-03-16T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7996.73',
#    'open_equity': '0.89',
#    'close_equity': '0.89',
#    'open_market_value': '0',
#    'close_market_value': '0',
#    'begins_at': '2020-03-23T00:00:00Z',
#    'net_return': '0',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7996.73',
#    'adjusted_close_equity': '7954.45',
#    'open_equity': '0.89',
#    'close_equity': '558.61',
#    'open_market_value': '0',
#    'close_market_value': '546.34',
#    'begins_at': '2020-03-30T00:00:00Z',
#    'net_return': '626.6517',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7957.8821',
#    'adjusted_close_equity': '7986.99',
#    'open_equity': '562.0421',
#    'close_equity': '591.15',
#    'open_market_value': '549.7721',
#    'close_market_value': '578.88',
#    'begins_at': '2020-04-06T00:00:00Z',
#    'net_return': '0.0518',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7993.23',
#    'adjusted_close_equity': '7978.35',
#    'open_equity': '597.39',
#    'close_equity': '582.51',
#    'open_market_value': '585.12',
#    'close_market_value': '570.24',
#    'begins_at': '2020-04-13T00:00:00Z',
#    'net_return': '-0.0249',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7966.88',
#    'adjusted_close_equity': '7920.595',
#    'open_equity': '571.04',
#    'close_equity': '724.755',
#    'open_market_value': '558.77',
#    'close_market_value': '714.255',
#    'begins_at': '2020-04-20T00:00:00Z',
#    'net_return': '0.2692',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7927.56',
#    'adjusted_close_equity': '7909.21',
#    'open_equity': '731.72',
#    'close_equity': '713.37',
#    'open_market_value': '721.22',
#    'close_market_value': '702.87',
#    'begins_at': '2020-04-27T00:00:00Z',
#    'net_return': '-0.0251',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7880.03',
#    'adjusted_close_equity': '7928.0156',
#    'open_equity': '684.19',
#    'close_equity': '1289.7656',
#    'open_market_value': '673.69',
#    'close_market_value': '1284.4256',
#    'begins_at': '2020-05-04T00:00:00Z',
#    'net_return': '0.8851',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7921.16',
#    'adjusted_close_equity': '7851.4684',
#    'open_equity': '1282.91',
#    'close_equity': '2011.7084',
#    'open_market_value': '1277.57',
#    'close_market_value': '2005.7084',
#    'begins_at': '2020-05-11T00:00:00Z',
#    'net_return': '0.5681',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7616.86',
#    'adjusted_close_equity': '7846.456',
#    'open_equity': '1777.1',
#    'close_equity': '2006.696',
#    'open_market_value': '1771.1',
#    'close_market_value': '2000.696',
#    'begins_at': '2020-05-18T00:00:00Z',
#    'net_return': '0.1292',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7670.53',
#    'adjusted_close_equity': '7871.62',
#    'open_equity': '1830.77',
#    'close_equity': '2031.86',
#    'open_market_value': '1824.77',
#    'close_market_value': '2025.86',
#    'begins_at': '2020-05-25T00:00:00Z',
#    'net_return': '0.1098',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7872.8835',
#    'adjusted_close_equity': '7913.902',
#    'open_equity': '2033.1235',
#    'close_equity': '2074.142',
#    'open_market_value': '2027.1235',
#    'close_market_value': '2068.142',
#    'begins_at': '2020-06-01T00:00:00Z',
#    'net_return': '0.0202',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7734.07',
#    'adjusted_close_equity': '7831.03970958',
#    'open_equity': '1894.31',
#    'close_equity': '2395.27970958',
#    'open_market_value': '1888.31',
#    'close_market_value': '2373.59970958',
#    'begins_at': '2020-06-08T00:00:00Z',
#    'net_return': '0.2645',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7943.24837064',
#    'adjusted_close_equity': '7980.72355429',
#    'open_equity': '2507.48837064',
#    'close_equity': '3163.28355429',
#    'open_market_value': '2485.80837064',
#    'close_market_value': '3123.28355429',
#    'begins_at': '2020-06-15T00:00:00Z',
#    'net_return': '0.2615',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7787.69857749',
#    'adjusted_close_equity': '7989.77683698',
#    'open_equity': '2970.25857749',
#    'close_equity': '3523.36683698',
#    'open_market_value': '2930.25857749',
#    'close_market_value': '3385.16683698',
#    'begins_at': '2020-06-22T00:00:00Z',
#    'net_return': '0.1862',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7331.99138952',
#    'adjusted_close_equity': '8045.79117698',
#    'open_equity': '2865.58138952',
#    'close_equity': '3719.14117698',
#    'open_market_value': '2727.38138952',
#    'close_market_value': '3719.14117698',
#    'begins_at': '2020-06-29T00:00:00Z',
#    'net_return': '0.2979',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8033.3024735245',
#    'adjusted_close_equity': '8276.0248958976',
#    'open_equity': '3706.6524735245',
#    'close_equity': '4784.8848958976',
#    'open_market_value': '3706.6524735245',
#    'close_market_value': '4513.3848958976',
#    'begins_at': '2020-07-06T00:00:00Z',
#    'net_return': '0.2909',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8308.20143393',
#    'adjusted_close_equity': '8238.10648997',
#    'open_equity': '4817.06143393',
#    'close_equity': '5103.32648997',
#    'open_market_value': '4545.56143393',
#    'close_market_value': '5086.29648997',
#    'begins_at': '2020-07-13T00:00:00Z',
#    'net_return': '0.0594',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7852.603137575',
#    'adjusted_close_equity': '8093.335095159',
#    'open_equity': '4717.823137575',
#    'close_equity': '5304.645095159',
#    'open_market_value': '4700.793137575',
#    'close_market_value': '5163.985095159',
#    'begins_at': '2020-07-20T00:00:00Z',
#    'net_return': '0.1244',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8317.17908099',
#    'adjusted_close_equity': '8176.7282279496',
#    'open_equity': '5528.48908099',
#    'close_equity': '5388.0382279496',
#    'open_market_value': '5387.82908099',
#    'close_market_value': '5364.4382279496',
#    'begins_at': '2020-07-27T00:00:00Z',
#    'net_return': '-0.0254',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8039.33764639',
#    'adjusted_close_equity': '8130.5461963',
#    'open_equity': '5250.64764639',
#    'close_equity': '7696.2661963',
#    'open_market_value': '5227.04764639',
#    'close_market_value': '5661.6761963',
#    'begins_at': '2020-08-03T00:00:00Z',
#    'net_return': '0.4658',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8149.5804312',
#    'adjusted_close_equity': '7785.31811056',
#    'open_equity': '7715.3004312',
#    'close_equity': '13765.10811056',
#    'open_market_value': '5680.7104312',
#    'close_market_value': '10484.56811056',
#    'begins_at': '2020-08-10T00:00:00Z',
#    'net_return': '0.7841',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7867.99500781',
#    'adjusted_close_equity': '7748.24594581',
#    'open_equity': '13847.78500781',
#    'close_equity': '15865.41594581',
#    'open_market_value': '10567.24500781',
#    'close_market_value': '12804.58594581',
#    'begins_at': '2020-08-17T00:00:00Z',
#    'net_return': '0.1457',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8506.07820253',
#    'adjusted_close_equity': '8388.22760825',
#    'open_equity': '16623.24820253',
#    'close_equity': '18049.81760825',
#    'open_market_value': '13562.41820253',
#    'close_market_value': '14946.18760825',
#    'begins_at': '2020-08-24T00:00:00Z',
#    'net_return': '0.0858',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8070.61461021',
#    'adjusted_close_equity': '8011.5084765688',
#    'open_equity': '17732.20461021',
#    'close_equity': '19025.2384765688',
#    'open_market_value': '14628.57461021',
#    'close_market_value': '14632.5884765688',
#    'begins_at': '2020-08-31T00:00:00Z',
#    'net_return': '0.0729',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7486.24634216',
#    'adjusted_close_equity': '7917.216512044',
#    'open_equity': '18499.97634216',
#    'close_equity': '18930.946512044',
#    'open_market_value': '14107.32634216',
#    'close_market_value': '14101.586512044',
#    'begins_at': '2020-09-07T00:00:00Z',
#    'net_return': '0.0233',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8020.21783089',
#    'adjusted_close_equity': '7891.41734262',
#    'open_equity': '19033.94783089',
#    'close_equity': '18905.14734262',
#    'open_market_value': '14204.58783089',
#    'close_market_value': '15395.44734262',
#    'begins_at': '2020-09-14T00:00:00Z',
#    'net_return': '-0.0068',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7782.7944564',
#    'adjusted_close_equity': '7304.1512163736',
#    'open_equity': '18796.5244564',
#    'close_equity': '18317.8812163736',
#    'open_market_value': '15286.8244564',
#    'close_market_value': '18272.0412163736',
#    'begins_at': '2020-09-21T00:00:00Z',
#    'net_return': '-0.0255',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7398.99175989',
#    'adjusted_close_equity': '7558.9193502706',
#    'open_equity': '18412.72175989',
#    'close_equity': '18572.6493502706',
#    'open_market_value': '18366.88175989',
#    'close_market_value': '18143.7793502706',
#    'begins_at': '2020-09-28T00:00:00Z',
#    'net_return': '0.0087',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7773.38632915',
#    'adjusted_close_equity': '8091.2082507722',
#    'open_equity': '18787.11632915',
#    'close_equity': '19104.9382507722',
#    'open_market_value': '18358.24632915',
#    'close_market_value': '19103.2882507722',
#    'begins_at': '2020-10-05T00:00:00Z',
#    'net_return': '0.0169',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8186.3188481068',
#    'adjusted_close_equity': '8026.7893911396',
#    'open_equity': '19200.0488481068',
#    'close_equity': '19750.5193911396',
#    'open_market_value': '19198.3988481068',
#    'close_market_value': '19685.0093911396',
#    'begins_at': '2020-10-12T00:00:00Z',
#    'net_return': '0.0287',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8042.4103335496',
#    'adjusted_close_equity': '7901.07632702',
#    'open_equity': '19766.1403335496',
#    'close_equity': '19624.80632702',
#    'open_market_value': '19700.6303335496',
#    'close_market_value': '19126.31632702',
#    'begins_at': '2020-10-19T00:00:00Z',
#    'net_return': '-0.0072',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7632.58617316',
#    'adjusted_close_equity': '6981.1171157',
#    'open_equity': '19356.31617316',
#    'close_equity': '20324.8471157',
#    'open_market_value': '18857.82617316',
#    'close_market_value': '19853.5371157',
#    'begins_at': '2020-10-26T00:00:00Z',
#    'net_return': '0.05',
#    'session': 'reg'},
#   {'adjusted_open_equity': '7228.88680607',
#    'adjusted_close_equity': '9127.48410284843201',
#    'open_equity': '20572.61680607',
#    'close_equity': '23071.21410284843201',
#    'open_market_value': '20101.30680607',
#    'close_market_value': '22195.69410284843201',
#    'begins_at': '2020-11-02T00:00:00Z',
#    'net_return': '0.1215',
#    'session': 'reg'},
#   {'adjusted_open_equity': '9316.51447464665785',
#    'adjusted_close_equity': '8675.34413297',
#    'open_equity': '23260.24447464665785',
#    'close_equity': '22619.07413297',
#    'open_market_value': '22384.72447464665785',
#    'close_market_value': '22333.71413297',
#    'begins_at': '2020-11-09T00:00:00Z',
#    'net_return': '-0.0276',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8913.20366147',
#    'adjusted_close_equity': '8854.92146348',
#    'open_equity': '22856.93366147',
#    'close_equity': '22798.65146348',
#    'open_market_value': '22571.57366147',
#    'close_market_value': '22594.61146348',
#    'begins_at': '2020-11-16T00:00:00Z',
#    'net_return': '-0.0025',
#    'session': 'reg'},
#   {'adjusted_open_equity': '8968.37284747',
#    'adjusted_close_equity': '10301.87059151',
#    'open_equity': '22912.10284747',
#    'close_equity': '24645.60059151',
#    'open_market_value': '22708.06284747',
#    'close_market_value': '22745.64059151',
#    'begins_at': '2020-11-23T00:00:00Z',
#    'net_return': '0.0757',
#    'session': 'reg'},
#   {'adjusted_open_equity': '10075.4125166',
#    'adjusted_close_equity': '10193.88607484',
#    'open_equity': '24419.1425166',
#    'close_equity': '24537.61607484',
#    'open_market_value': '22519.1825166',
#    'close_market_value': '23457.05607484',
#    'begins_at': '2020-11-30T00:00:00Z',
#    'net_return': '0.0049',
#    'session': 'reg'},
#   {'adjusted_open_equity': '9906.97753327',
#    'adjusted_close_equity': '10303.57301034',
#    'open_equity': '24250.70753327',
#    'close_equity': '25097.30301034',
#    'open_market_value': '23170.14753327',
#    'close_market_value': '24686.47301034',
#    'begins_at': '2020-12-07T00:00:00Z',
#    'net_return': '0.0349',
#    'session': 'reg'},
#   {'adjusted_open_equity': '10353.2300269',
#    'adjusted_close_equity': '10575.84882415',
#    'open_equity': '25146.9600269',
#    'close_equity': '25669.57882415',
#    'open_market_value': '24736.1300269',
#    'close_market_value': '25252.44882415',
#    'begins_at': '2020-12-14T00:00:00Z',
#    'net_return': '0.0208',
#    'session': 'reg'},
#   {'adjusted_open_equity': '10516.75684755',
#    'adjusted_close_equity': '10914.06987038',
#    'open_equity': '25610.48684755',
#    'close_equity': '26007.79987038',
#    'open_market_value': '25193.35684755',
#    'close_market_value': '24393.02987038',
#    'begins_at': '2020-12-21T00:00:00Z',
#    'net_return': '0.0155',
#    'session': 'reg'},
#   {'adjusted_open_equity': '11084.96159411',
#    'adjusted_close_equity': '10764.70173984',
#    'open_equity': '26178.69159411',
#    'close_equity': '25858.43173984',
#    'open_market_value': '24563.92159411',
#    'close_market_value': '24360.43173984',
#    'begins_at': '2020-12-28T00:00:00Z',
#    'net_return': '-0.0122',
#    'session': 'reg'},
#   {'adjusted_open_equity': '11440.45747469',
#    'adjusted_close_equity': '11824.14181429',
#    'open_equity': '26534.18747469',
#    'close_equity': '26917.87181429',
#    'open_market_value': '25036.18747469',
#    'close_market_value': '25789.80181429',
#    'begins_at': '2021-01-04T00:00:00Z',
#    'net_return': '0.0145',
#    'session': 'reg'},
#   {'adjusted_open_equity': '11569.06094249',
#    'adjusted_close_equity': '12274.23251654',
#    'open_equity': '26662.79094249',
#    'close_equity': '28367.96251654',
#    'open_market_value': '25534.72094249',
#    'close_market_value': '27228.12251654',
#    'begins_at': '2021-01-11T00:00:00Z',
#    'net_return': '0.064',
#    'session': 'reg'},
#   {'adjusted_open_equity': '12746.86937419',
#    'adjusted_close_equity': '14868.24487374',
#    'open_equity': '28840.59937419',
#    'close_equity': '31961.97487374',
#    'open_market_value': '27700.75937419',
#    'close_market_value': '29698.13487374',
#    'begins_at': '2021-01-18T00:00:00Z',
#    'net_return': '0.1082',
#    'session': 'reg'},
#   {'adjusted_open_equity': '16062.48339391',
#    'adjusted_close_equity': '24924.51727250335259',
#    'open_equity': '33156.21339391',
#    'close_equity': '28018.24727250335259',
#    'open_market_value': '30892.37339391',
#    'close_market_value': '27794.04727250335259',
#    'begins_at': '2021-01-25T00:00:00Z',
#    'net_return': '-0.155',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24916.54465445578186',
#    'adjusted_close_equity': '27216.21428078116807',
#    'open_equity': '28010.27465445578186',
#    'close_equity': '30609.94428078116807',
#    'open_market_value': '27786.07465445578186',
#    'close_market_value': '30353.51428078116807',
#    'begins_at': '2021-02-01T00:00:00Z',
#    'net_return': '0.0928',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27397.97892848186966',
#    'adjusted_close_equity': '28380.33783106983608',
#    'open_equity': '30791.70892848186966',
#    'close_equity': '31774.06783106983608',
#    'open_market_value': '30535.27892848186966',
#    'close_market_value': '31735.53783106983608',
#    'begins_at': '2021-02-08T00:00:00Z',
#    'net_return': '0.0319',
#    'session': 'reg'},
#   {'adjusted_open_equity': '28757.65550914983608',
#    'adjusted_close_equity': '27870.51113254262482',
#    'open_equity': '32151.38550914983608',
#    'close_equity': '33264.24113254262482',
#    'open_market_value': '32112.85550914983608',
#    'close_market_value': '32223.70113254262482',
#    'begins_at': '2021-02-15T00:00:00Z',
#    'net_return': '0.0346',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27934.52868276165557',
#    'adjusted_close_equity': '26262.82976395',
#    'open_equity': '33328.25868276165557',
#    'close_equity': '33656.55976395',
#    'open_market_value': '32287.71868276165557',
#    'close_market_value': '29486.06976395',
#    'begins_at': '2021-02-22T00:00:00Z',
#    'net_return': '0.0099',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26230.22793477',
#    'adjusted_close_equity': '26883.45602276',
#    'open_equity': '33623.95793477',
#    'close_equity': '35277.18602276',
#    'open_market_value': '29453.46793477',
#    'close_market_value': '33507.78602276',
#    'begins_at': '2021-03-01T00:00:00Z',
#    'net_return': '0.0492',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26350.15339407',
#    'adjusted_close_equity': '27063.57289965',
#    'open_equity': '34743.88339407',
#    'close_equity': '35457.30289965',
#    'open_market_value': '32974.48339407',
#    'close_market_value': '35453.75289965',
#    'begins_at': '2021-03-08T00:00:00Z',
#    'net_return': '0.0205',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26386.2441014876',
#    'adjusted_close_equity': '26106.69818329026016',
#    'open_equity': '34779.9741014876',
#    'close_equity': '38500.42818329026016',
#    'open_market_value': '34776.4241014876',
#    'close_market_value': '37301.21818329026016',
#    'begins_at': '2021-03-15T00:00:00Z',
#    'net_return': '0.107',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25388.6941857933264',
#    'adjusted_close_equity': '26250.36230707011264',
#    'open_equity': '37782.4241857933264',
#    'close_equity': '38644.09230707011264',
#    'open_market_value': '36583.2141857933264',
#    'close_market_value': '36846.25230707011264',
#    'begins_at': '2021-03-22T00:00:00Z',
#    'net_return': '0.0228',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25905.48876411797024',
#    'adjusted_close_equity': '26040.66911085355376',
#    'open_equity': '38299.21876411797024',
#    'close_equity': '38434.39911085355376',
#    'open_market_value': '36501.37876411797024',
#    'close_market_value': '35989.29911085355376',
#    'begins_at': '2021-03-29T00:00:00Z',
#    'net_return': '0.0035',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26311.35037954855376',
#    'adjusted_close_equity': '26652.14014809448422',
#    'open_equity': '38705.08037954855376',
#    'close_equity': '39045.87014809448422',
#    'open_market_value': '36259.98037954855376',
#    'close_market_value': '37781.86014809448422',
#    'begins_at': '2021-04-05T00:00:00Z',
#    'net_return': '0.0088',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26516.87621214674771',
#    'adjusted_close_equity': '27496.44034907259458',
#    'open_equity': '38910.60621214674771',
#    'close_equity': '40890.17034907259458',
#    'open_market_value': '37646.59621214674771',
#    'close_market_value': '40818.02034907259458',
#    'begins_at': '2021-04-12T00:00:00Z',
#    'net_return': '0.0509',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27444.99498734197236',
#    'adjusted_close_equity': '26689.73300585879044',
#    'open_equity': '40838.72498734197236',
#    'close_equity': '40783.46300585879044',
#    'open_market_value': '40766.57498734197236',
#    'close_market_value': '40727.84300585879044',
#    'begins_at': '2021-04-19T00:00:00Z',
#    'net_return': '-0.0014',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26802.76192660919426',
#    'adjusted_close_equity': '26879.56775994214288',
#    'open_equity': '40896.49192660919426',
#    'close_equity': '40973.29775994214288',
#    'open_market_value': '40840.87192660919426',
#    'close_market_value': '40269.68775994214288',
#    'begins_at': '2021-04-26T00:00:00Z',
#    'net_return': '0.0019',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27253.73746497672756',
#    'adjusted_close_equity': '27130.81677859435575',
#    'open_equity': '41347.46746497672756',
#    'close_equity': '41224.54677859435575',
#    'open_market_value': '40643.85746497672756',
#    'close_market_value': '40257.91677859435575',
#    'begins_at': '2021-05-03T00:00:00Z',
#    'net_return': '-0.003',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27318.3160411375833',
#    'adjusted_close_equity': '26098.20555647327844',
#    'open_equity': '41412.0460411375833',
#    'close_equity': '40191.93555647327844',
#    'open_market_value': '40445.4160411375833',
#    'close_market_value': '39898.39555647327844',
#    'begins_at': '2021-05-10T00:00:00Z',
#    'net_return': '-0.0295',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26135.24230410933296',
#    'adjusted_close_equity': '25037.06578874262519',
#    'open_equity': '40228.97230410933296',
#    'close_equity': '40130.79578874262519',
#    'open_market_value': '39935.43230410933296',
#    'close_market_value': '39995.92578874262519',
#    'begins_at': '2021-05-17T00:00:00Z',
#    'net_return': '-0.0024',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25136.82585909499014',
#    'adjusted_close_equity': '25441.9489353752482',
#    'open_equity': '40230.55585909499014',
#    'close_equity': '41325.6789353752482',
#    'open_market_value': '40095.68585909499014',
#    'close_market_value': '40785.7289353752482',
#    'begins_at': '2021-05-24T00:00:00Z',
#    'net_return': '0.0272',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25739.7776085322482',
#    'adjusted_close_equity': '26201.42776712933508',
#    'open_equity': '41623.5076085322482',
#    'close_equity': '42085.15776712933508',
#    'open_market_value': '41083.5576085322482',
#    'close_market_value': '41532.64776712933508',
#    'begins_at': '2021-05-31T00:00:00Z',
#    'net_return': '0.0111',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25868.13122791658808',
#    'adjusted_close_equity': '26257.8096608201376',
#    'open_equity': '41751.86122791658808',
#    'close_equity': '42141.5396608201376',
#    'open_market_value': '41199.35122791658808',
#    'close_market_value': '41768.5796608201376',
#    'begins_at': '2021-06-07T00:00:00Z',
#    'net_return': '0.0093',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26273.04155696189645',
#    'adjusted_close_equity': '24531.66256738532914',
#    'open_equity': '42156.77155696189645',
#    'close_equity': '41415.39256738532914',
#    'open_market_value': '41783.81155696189645',
#    'close_market_value': '40879.52256738532914',
#    'begins_at': '2021-06-14T00:00:00Z',
#    'net_return': '-0.0176',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24570.14670095495332',
#    'adjusted_close_equity': '25207.51294584392974',
#    'open_equity': '41453.87670095495332',
#    'close_equity': '42091.24294584392974',
#    'open_market_value': '40918.00670095495332',
#    'close_market_value': '41996.81294584392974',
#    'begins_at': '2021-06-21T00:00:00Z',
#    'net_return': '0.0154',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25088.5247057357172',
#    'adjusted_close_equity': '25302.44653890193888',
#    'open_equity': '41972.2547057357172',
#    'close_equity': '44186.17653890193888',
#    'open_market_value': '41877.8247057357172',
#    'close_market_value': '42208.39653890193888',
#    'begins_at': '2021-06-28T00:00:00Z',
#    'net_return': '0.0527',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25286.58012782398886',
#    'adjusted_close_equity': '25282.53736566983974',
#    'open_equity': '44170.31012782398886',
#    'close_equity': '44166.26736566983974',
#    'open_market_value': '42192.53012782398886',
#    'close_market_value': '42170.41736566983974',
#    'begins_at': '2021-07-05T00:00:00Z',
#    'net_return': '-0.0001',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25304.30164620042368',
#    'adjusted_close_equity': '24463.49893327',
#    'open_equity': '44188.03164620042368',
#    'close_equity': '43347.22893327',
#    'open_market_value': '42192.18164620042368',
#    'close_market_value': '40465.55893327',
#    'begins_at': '2021-07-12T00:00:00Z',
#    'net_return': '-0.019',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24033.2152403371',
#    'adjusted_close_equity': '25299.11969902',
#    'open_equity': '42916.9452403371',
#    'close_equity': '44182.84969902',
#    'open_market_value': '40035.2752403371',
#    'close_market_value': '43767.62969902',
#    'begins_at': '2021-07-19T00:00:00Z',
#    'net_return': '0.0295',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25387.037878535',
#    'adjusted_close_equity': '25928.81767864',
#    'open_equity': '44270.767878535',
#    'close_equity': '44812.54767864',
#    'open_market_value': '43855.547878535',
#    'close_market_value': '44618.78767864',
#    'begins_at': '2021-07-26T00:00:00Z',
#    'net_return': '0.0122',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26444.76947616',
#    'adjusted_close_equity': '26857.84449597',
#    'open_equity': '45328.49947616',
#    'close_equity': '45741.57449597',
#    'open_market_value': '45134.73947616',
#    'close_market_value': '45547.22449597',
#    'begins_at': '2021-08-02T00:00:00Z',
#    'net_return': '0.0091',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27217.70988052',
#    'adjusted_close_equity': '26804.45611823',
#    'open_equity': '46101.43988052',
#    'close_equity': '46208.18611823',
#    'open_market_value': '45907.08988052',
#    'close_market_value': '46034.74611823',
#    'begins_at': '2021-08-09T00:00:00Z',
#    'net_return': '0.0023',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26923.56628788',
#    'adjusted_close_equity': '25859.61141037',
#    'open_equity': '46327.29628788',
#    'close_equity': '47763.34141037',
#    'open_market_value': '46153.85628788',
#    'close_market_value': '46713.85141037',
#    'begins_at': '2021-08-16T00:00:00Z',
#    'net_return': '0.031',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26496.943853695',
#    'adjusted_close_equity': '26941.6858013',
#    'open_equity': '48400.673853695',
#    'close_equity': '48845.4158013',
#    'open_market_value': '47351.183853695',
#    'close_market_value': '47794.5458013',
#    'begins_at': '2021-08-23T00:00:00Z',
#    'net_return': '0.0092',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26971.474362645',
#    'adjusted_close_equity': '27262.69275176',
#    'open_equity': '48875.204362645',
#    'close_equity': '49166.42275176',
#    'open_market_value': '47824.334362645',
#    'close_market_value': '49149.46275176',
#    'begins_at': '2021-08-30T00:00:00Z',
#    'net_return': '0.006',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27542.97729895',
#    'adjusted_close_equity': '26968.08919993',
#    'open_equity': '49446.70729895',
#    'close_equity': '48871.81919993',
#    'open_market_value': '49429.74729895',
#    'close_market_value': '48834.61919993',
#    'begins_at': '2021-09-06T00:00:00Z',
#    'net_return': '-0.0116',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27456.46181567',
#    'adjusted_close_equity': '27200.378781',
#    'open_equity': '49360.19181567',
#    'close_equity': '50104.108781',
#    'open_market_value': '49322.99181567',
#    'close_market_value': '49152.838781',
#    'begins_at': '2021-09-13T00:00:00Z',
#    'net_return': '0.0151',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25534.6661864041',
#    'adjusted_close_equity': '27242.07035339',
#    'open_equity': '48438.3961864041',
#    'close_equity': '51145.80035339',
#    'open_market_value': '47487.1261864041',
#    'close_market_value': '51043.97035339',
#    'begins_at': '2021-09-20T00:00:00Z',
#    'net_return': '0.0559',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27174.52495516',
#    'adjusted_close_equity': '25007.16001565',
#    'open_equity': '51078.25495516',
#    'close_equity': '49910.89001565',
#    'open_market_value': '50976.42495516',
#    'close_market_value': '49677.27001565',
#    'begins_at': '2021-09-27T00:00:00Z',
#    'net_return': '-0.0229',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24764.32913591',
#    'adjusted_close_equity': '25153.84864127',
#    'open_equity': '49668.05913591',
#    'close_equity': '50057.57864127',
#    'open_market_value': '49434.43913591',
#    'close_market_value': '49618.34864127',
#    'begins_at': '2021-10-04T00:00:00Z',
#    'net_return': '0.0078',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24435.715511585',
#    'adjusted_close_equity': '26587.29685145',
#    'open_equity': '49339.445511585',
#    'close_equity': '51491.02685145',
#    'open_market_value': '48900.215511585',
#    'close_market_value': '48977.40685145',
#    'begins_at': '2021-10-11T00:00:00Z',
#    'net_return': '0.0436',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26513.29332001',
#    'adjusted_close_equity': '28135.527462',
#    'open_equity': '51417.02332001',
#    'close_equity': '53039.257462',
#    'open_market_value': '48903.40332001',
#    'close_market_value': '50522.037462',
#    'begins_at': '2021-10-18T00:00:00Z',
#    'net_return': '0.0316',
#    'session': 'reg'},
#   {'adjusted_open_equity': '28172.34061008',
#    'adjusted_close_equity': '29245.91743886',
#    'open_equity': '53076.07061008',
#    'close_equity': '54149.64743886',
#    'open_market_value': '50558.85061008',
#    'close_market_value': '51624.28743886',
#    'begins_at': '2021-10-25T00:00:00Z',
#    'net_return': '0.0202',
#    'session': 'reg'},
#   {'adjusted_open_equity': '29575.03970655',
#    'adjusted_close_equity': '29523.86119595',
#    'open_equity': '54478.76970655',
#    'close_equity': '54427.59119595',
#    'open_market_value': '51953.40970655',
#    'close_market_value': '53978.95119595',
#    'begins_at': '2021-11-01T00:00:00Z',
#    'net_return': '-0.0009',
#    'session': 'reg'},
#   {'adjusted_open_equity': '29670.52515664',
#    'adjusted_close_equity': '30137.02375112',
#    'open_equity': '54574.25515664',
#    'close_equity': '55540.75375112',
#    'open_market_value': '54125.61515664',
#    'close_market_value': '55233.56375112',
#    'begins_at': '2021-11-08T00:00:00Z',
#    'net_return': '0.0177',
#    'session': 'reg'},
#   {'adjusted_open_equity': '30403.69968214',
#    'adjusted_close_equity': '31415.23673884397517',
#    'open_equity': '55807.42968214',
#    'close_equity': '56818.96673884397517',
#    'open_market_value': '55500.23968214',
#    'close_market_value': '56519.07673884397517',
#    'begins_at': '2021-11-15T00:00:00Z',
#    'net_return': '0.0181',
#    'session': 'reg'},
#   {'adjusted_open_equity': '31806.26118238382021',
#    'adjusted_close_equity': '30430.47796720388443',
#    'open_equity': '57209.99118238382021',
#    'close_equity': '55834.20796720388443',
#    'open_market_value': '56910.10118238382021',
#    'close_market_value': '55662.92796720388443',
#    'begins_at': '2021-11-22T00:00:00Z',
#    'net_return': '-0.024',
#    'session': 'reg'},
#   {'adjusted_open_equity': '31494.76905951508499',
#    'adjusted_close_equity': '28533.9072732883149',
#    'open_equity': '56898.49905951508499',
#    'close_equity': '53937.6372732883149',
#    'open_market_value': '56727.21905951508499',
#    'close_market_value': '53751.0772732883149',
#    'begins_at': '2021-11-29T00:00:00Z',
#    'net_return': '-0.052',
#    'session': 'reg'},
#   {'adjusted_open_equity': '28204.88902923889977',
#    'adjusted_close_equity': '28868.2853091265262',
#    'open_equity': '53608.61902923889977',
#    'close_equity': '54272.0153091265262',
#    'open_market_value': '53422.05902923889977',
#    'close_market_value': '54214.5553091265262',
#    'begins_at': '2021-12-06T00:00:00Z',
#    'net_return': '0.0124',
#    'session': 'reg'},
#   {'adjusted_open_equity': '28922.74884177783324',
#    'adjusted_close_equity': '27044.98556931718056',
#    'open_equity': '54326.47884177783324',
#    'close_equity': '52448.71556931718056',
#    'open_market_value': '54269.01884177783324',
#    'close_market_value': '52413.41556931718056',
#    'begins_at': '2021-12-13T00:00:00Z',
#    'net_return': '-0.0346',
#    'session': 'reg'},
#   {'adjusted_open_equity': '26520.93251394',
#    'adjusted_close_equity': '27912.349570625',
#    'open_equity': '51924.66251394',
#    'close_equity': '53316.079570625',
#    'open_market_value': '51889.36251394',
#    'close_market_value': '53250.979570625',
#    'begins_at': '2021-12-20T00:00:00Z',
#    'net_return': '0.0268',
#    'session': 'reg'},
#   {'adjusted_open_equity': '27949.616708295',
#    'adjusted_close_equity': '28254.03260285',
#    'open_equity': '53353.346708295',
#    'close_equity': '53657.76260285',
#    'open_market_value': '53288.246708295',
#    'close_market_value': '53505.08260285',
#    'begins_at': '2021-12-27T00:00:00Z',
#    'net_return': '0.0057',
#    'session': 'reg'},
#   {'adjusted_open_equity': '28251.15226473',
#    'adjusted_close_equity': '26286.65315435',
#    'open_equity': '53654.88226473',
#    'close_equity': '51690.38315435',
#    'open_market_value': '53502.20226473',
#    'close_market_value': '50980.73315435',
#    'begins_at': '2022-01-03T00:00:00Z',
#    'net_return': '-0.0366',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25964.235061235',
#    'adjusted_close_equity': '26111.108731465',
#    'open_equity': '51367.965061235',
#    'close_equity': '52214.838731465',
#    'open_market_value': '50658.315061235',
#    'close_market_value': '51751.488731465',
#    'begins_at': '2022-01-10T00:00:00Z',
#    'net_return': '0.0165',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25550.410672515',
#    'adjusted_close_equity': '23225.679124935',
#    'open_equity': '51654.140672515',
#    'close_equity': '49329.409124935',
#    'open_market_value': '51190.790672515',
#    'close_market_value': '47826.869124935',
#    'begins_at': '2022-01-17T00:00:00Z',
#    'net_return': '-0.045',
#    'session': 'reg'},
#   {'adjusted_open_equity': '22548.654891005',
#    'adjusted_close_equity': '23744.64366815',
#    'open_equity': '48652.384891005',
#    'close_equity': '49848.37366815',
#    'open_market_value': '47149.844891005',
#    'close_market_value': '49314.83366815',
#    'begins_at': '2022-01-24T00:00:00Z',
#    'net_return': '0.0246',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24238.51229256',
#    'adjusted_close_equity': '24979.10879374',
#    'open_equity': '50342.24229256',
#    'close_equity': '51082.89879374',
#    'open_market_value': '49808.70229256',
#    'close_market_value': '47364.49879374',
#    'begins_at': '2022-01-31T00:00:00Z',
#    'net_return': '0.0147',
#    'session': 'reg'},
#   {'adjusted_open_equity': '25040.393387355',
#    'adjusted_close_equity': '24155.71706284',
#    'open_equity': '51144.183387355',
#    'close_equity': '47259.50706284',
#    'open_market_value': '47425.783387355',
#    'close_market_value': '46856.54706284',
#    'begins_at': '2022-02-07T00:00:00Z',
#    'net_return': '-0.076',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24054.235570165',
#    'adjusted_close_equity': '22648.96028614',
#    'open_equity': '47158.025570165',
#    'close_equity': '45752.75028614',
#    'open_market_value': '46755.065570165',
#    'close_market_value': '45670.46028614',
#    'begins_at': '2022-02-14T00:00:00Z',
#    'net_return': '-0.0298',
#    'session': 'reg'},
#   {'adjusted_open_equity': '22549.07403348',
#    'adjusted_close_equity': '22913.80099552',
#    'open_equity': '45652.86403348',
#    'close_equity': '46017.59099552',
#    'open_market_value': '45570.57403348',
#    'close_market_value': '45389.91099552',
#    'begins_at': '2022-02-21T00:00:00Z',
#    'net_return': '0.008',
#    'session': 'reg'},
#   {'adjusted_open_equity': '22717.32825662',
#    'adjusted_close_equity': '23645.33193285',
#    'open_equity': '45821.11825662',
#    'close_equity': '46749.12193285',
#    'open_market_value': '45193.43825662',
#    'close_market_value': '46194.89193285',
#    'begins_at': '2022-02-28T00:00:00Z',
#    'net_return': '0.0203',
#    'session': 'reg'},
#   {'adjusted_open_equity': '23704.26277635',
#    'adjusted_close_equity': '22150.97004105',
#    'open_equity': '46808.05277635',
#    'close_equity': '45254.76004105',
#    'open_market_value': '46253.82277635',
#    'close_market_value': '43566.55004105',
#    'begins_at': '2022-03-07T00:00:00Z',
#    'net_return': '-0.0332',
#    'session': 'reg'},
#   {'adjusted_open_equity': '21974.62299909',
#    'adjusted_close_equity': '23511.02234608',
#    'open_equity': '45078.41299909',
#    'close_equity': '46614.81234608',
#    'open_market_value': '43390.20299909',
#    'close_market_value': '42834.92234608',
#    'begins_at': '2022-03-14T00:00:00Z',
#    'net_return': '0.0341',
#    'session': 'reg'},
#   {'adjusted_open_equity': '23577.4771101',
#    'adjusted_close_equity': '24247.85071147',
#    'open_equity': '46681.2671101',
#    'close_equity': '45351.64071147',
#    'open_market_value': '42901.3771101',
#    'close_market_value': '44897.49071147',
#    'begins_at': '2022-03-21T00:00:00Z',
#    'net_return': '-0.0285',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24032.87647107',
#    'adjusted_close_equity': '24174.48124214',
#    'open_equity': '45136.66647107',
#    'close_equity': '45278.27124214',
#    'open_market_value': '44682.51647107',
#    'close_market_value': '45181.72124214',
#    'begins_at': '2022-03-28T00:00:00Z',
#    'net_return': '0.0031',
#    'session': 'reg'},
#   {'adjusted_open_equity': '24317.84256048',
#    'adjusted_close_equity': '23412.40614123',
#    'open_equity': '45421.63256048',
#    'close_equity': '44516.19614123',
#    'open_market_value': '45325.08256048',
#    'close_market_value': '44352.24614123',
#    'begins_at': '2022-04-04T00:00:00Z',
#    'net_return': '-0.0199',
#    'session': 'reg'},
#   {'adjusted_open_equity': '23130.82016597',
#    'adjusted_close_equity': '22914.29406017',
#    'open_equity': '44234.61016597',
#    'close_equity': '44018.08406017',
#    'open_market_value': '44070.66016597',
#    'close_market_value': '43242.38406017',
#    'begins_at': '2022-04-11T00:00:00Z',
#    'net_return': '-0.0049',
#    'session': 'reg'},
#   {'adjusted_open_equity': '22881.82056702',
#    'adjusted_close_equity': '22385.2797547',
#    'open_equity': '43985.61056702',
#    'close_equity': '43489.0697547',
#    'open_market_value': '43209.91056702',
#    'close_market_value': '42897.4897547',
#    'begins_at': '2022-04-18T00:00:00Z',
#    'net_return': '-0.0113',
#    'session': 'reg'},
#   {'adjusted_open_equity': '22086.46786242',
#    'adjusted_close_equity': '21285.76731091',
#    'open_equity': '43190.25786242',
#    'close_equity': '42389.55731091',
#    'open_market_value': '42598.67786242',
#    'close_market_value': '31614.10731091',
#    'begins_at': '2022-04-25T00:00:00Z',
#    'net_return': '-0.0185',
#    'session': 'reg'},
#   {'adjusted_open_equity': '21224.20573782',
#    'adjusted_close_equity': '21462.86114037',
#    'open_equity': '42327.99573782',
#    'close_equity': '42566.65114037',
#    'open_market_value': '31552.54573782',
#    'close_market_value': '33872.63114037',
#    'begins_at': '2022-05-02T00:00:00Z',
#    'net_return': '0.0056',
#    'session': 'reg'},
#   {'adjusted_open_equity': '21416.16643304',
#    'adjusted_close_equity': '21611.51981882',
#    'open_equity': '42519.95643304',
#    'close_equity': '37715.30981882',
#    'open_market_value': '33825.93643304',
#    'close_market_value': '32852.89981882',
#    'begins_at': '2022-05-09T00:00:00Z',
#    'net_return': '-0.113',
#    'session': 'reg'},
#   {'adjusted_open_equity': '21610.31138417',
#    'adjusted_close_equity': '20451.55497361',
#    'open_equity': '37714.10138417',
#    'close_equity': '36555.34497361',
#    'open_market_value': '32851.69138417',
#    'close_market_value': '34504.35497361',
#    'begins_at': '2022-05-16T00:00:00Z',
#    'net_return': '-0.0307',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20525.30762192',
#    'adjusted_close_equity': '21365.57531274',
#    'open_equity': '36629.09762192',
#    'close_equity': '37469.36531274',
#    'open_market_value': '34578.10762192',
#    'close_market_value': '35514.18531274',
#    'begins_at': '2022-05-23T00:00:00Z',
#    'net_return': '0.0229',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20998.17909479',
#    'adjusted_close_equity': '21696.5438482',
#    'open_equity': '37101.96909479',
#    'close_equity': '37800.3338482',
#    'open_market_value': '35146.78909479',
#    'close_market_value': '37128.6738482',
#    'begins_at': '2022-05-30T00:00:00Z',
#    'net_return': '0.0188',
#    'session': 'reg'},
#   {'adjusted_open_equity': '19280.255635845',
#    'adjusted_close_equity': '20797.41453295',
#    'open_equity': '35384.045635845',
#    'close_equity': '36901.20453295',
#    'open_market_value': '34712.385635845',
#    'close_market_value': '36207.07453295',
#    'begins_at': '2022-06-06T00:00:00Z',
#    'net_return': '0.0429',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20742.04482684',
#    'adjusted_close_equity': '19589.80916524',
#    'open_equity': '36845.83482684',
#    'close_equity': '35693.59916524',
#    'open_market_value': '36151.70482684',
#    'close_market_value': '33704.23916524',
#    'begins_at': '2022-06-13T00:00:00Z',
#    'net_return': '-0.0313',
#    'session': 'reg'},
#   {'adjusted_open_equity': '19857.597904305',
#    'adjusted_close_equity': '21054.97804645',
#    'open_equity': '35961.387904305',
#    'close_equity': '37158.76804645',
#    'open_market_value': '33972.027904305',
#    'close_market_value': '35148.23804645',
#    'begins_at': '2022-06-20T00:00:00Z',
#    'net_return': '0.0333',
#    'session': 'reg'},
#   {'adjusted_open_equity': '21128.49732956',
#    'adjusted_close_equity': '20697.14157849',
#    'open_equity': '37232.28732956',
#    'close_equity': '36800.93157849',
#    'open_market_value': '35221.75732956',
#    'close_market_value': '35423.98157849',
#    'begins_at': '2022-06-27T00:00:00Z',
#    'net_return': '-0.0116',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20429.81127366',
#    'adjusted_close_equity': '20763.34490512',
#    'open_equity': '36533.60127366',
#    'close_equity': '36867.13490512',
#    'open_market_value': '35156.65127366',
#    'close_market_value': '35834.32490512',
#    'begins_at': '2022-07-04T00:00:00Z',
#    'net_return': '0.0091',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20593.41650309',
#    'adjusted_close_equity': '20492.47314438',
#    'open_equity': '36697.20650309',
#    'close_equity': '36596.26314438',
#    'open_market_value': '35664.39650309',
#    'close_market_value': '35544.72314438',
#    'begins_at': '2022-07-11T00:00:00Z',
#    'net_return': '-0.0028',
#    'session': 'reg'},
#   {'adjusted_open_equity': '18479.77299383',
#    'adjusted_close_equity': '20742.77179946',
#    'open_equity': '34583.56299383',
#    'close_equity': '36846.56179946',
#    'open_market_value': '33532.02299383',
#    'close_market_value': '29618.91179946',
#    'begins_at': '2022-07-18T00:00:00Z',
#    'net_return': '0.0654',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20764.211119335',
#    'adjusted_close_equity': '22142.39989396',
#    'open_equity': '36868.001119335',
#    'close_equity': '38248.63989396',
#    'open_market_value': '29640.351119335',
#    'close_market_value': '31009.01989396',
#    'begins_at': '2022-07-25T00:00:00Z',
#    'net_return': '0.0374',
#    'session': 'reg'},
#   {'adjusted_open_equity': '21935.0807101',
#    'adjusted_close_equity': '22314.49890679',
#    'open_equity': '38041.3207101',
#    'close_equity': '38420.73890679',
#    'open_market_value': '30801.7007101',
#    'close_market_value': '31167.20890679',
#    'begins_at': '2022-08-01T00:00:00Z',
#    'net_return': '0.01',
#    'session': 'reg'},
#   {'adjusted_open_equity': '22415.84472656',
#    'adjusted_close_equity': '23438.62191259',
#    'open_equity': '38522.08472656',
#    'close_equity': '39544.86191259',
#    'open_market_value': '31268.55472656',
#    'close_market_value': '34559.48191259',
#    'begins_at': '2022-08-08T00:00:00Z',
#    'net_return': '0.0266',
#    'session': 'reg'},
#   {'adjusted_open_equity': '23244.69836461',
#    'adjusted_close_equity': '22409.004649',
#    'open_equity': '39350.93836461',
#    'close_equity': '38515.244649',
#    'open_market_value': '34365.55836461',
#    'close_market_value': '38132.054649',
#    'begins_at': '2022-08-15T00:00:00Z',
#    'net_return': '-0.0212',
#    'session': 'reg'},
#   {'adjusted_open_equity': '21866.86273488',
#    'adjusted_close_equity': '21016.48959476',
#    'open_equity': '37973.10273488',
#    'close_equity': '38122.72959476',
#    'open_market_value': '37589.91273488',
#    'close_market_value': '37529.33959476',
#    'begins_at': '2022-08-22T00:00:00Z',
#    'net_return': '0.0039',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20752.83543411',
#    'adjusted_close_equity': '19500.61725532',
#    'open_equity': '37859.07543411',
#    'close_equity': '37610.35725532',
#    'open_market_value': '37265.68543411',
#    'close_market_value': '37586.32725532',
#    'begins_at': '2022-08-29T00:00:00Z',
#    'net_return': '-0.0066',
#    'session': 'reg'},
#   {'adjusted_open_equity': '19535.68179703',
#    'adjusted_close_equity': '20778.56280066',
#    'open_equity': '37645.42179703',
#    'close_equity': '38888.30280066',
#    'open_market_value': '37621.39179703',
#    'close_market_value': '38837.44280066',
#    'begins_at': '2022-09-05T00:00:00Z',
#    'net_return': '0.033',
#    'session': 'reg'},
#   {'adjusted_open_equity': '20927.92064445',
#    'adjusted_close_equity': '19018.53623516',
#    'open_equity': '39037.66064445',
#    'close_equity': '37128.27623516',
#    'open_market_value': '38986.80064445',
#    'close_market_value': '32704.89623516',
#    'begins_at': '2022-09-12T00:00:00Z',
#    'net_return': '-0.0489',
#    'session': 'reg'},
#   {'adjusted_open_equity': '18733.71795456',
#    'adjusted_close_equity': '18381.07',
#    'open_equity': '36843.45795456',
#    'close_equity': '13490.81',
#    'open_market_value': '32420.07795456',
#    'close_market_value': '12984.86',
#    'begins_at': '2022-09-19T00:00:00Z',
#    'net_return': '-0.6338',
#    'session': 'reg'},
#   {'adjusted_open_equity': '18297.84',
#    'adjusted_close_equity': '18627.53',
#    'open_equity': '13407.58',
#    'close_equity': '13738.95',
#    'open_market_value': '12901.63',
#    'close_market_value': '12963.97',
#    'begins_at': '2022-09-26T00:00:00Z',
#    'net_return': '0.0247',
#    'session': 'reg'},
#   {'adjusted_open_equity': '18760.05',
#    'adjusted_close_equity': '18777.2',
#    'open_equity': '13871.47',
#    'close_equity': '13888.62',
#    'open_market_value': '13096.49',
#    'close_market_value': '10912.19',
#    'begins_at': '2022-10-03T00:00:00Z',
#    'net_return': '0.0012',
#    'session': 'reg'},
#   {'adjusted_open_equity': '18774.62',
#    'adjusted_close_equity': '19177.92',
#    'open_equity': '13886.04',
#    'close_equity': '14289.34',
#    'open_market_value': '10909.61',
#    'close_market_value': '14234.28',
# ...
#    'open_market_value': '40714.99',
#    'close_market_value': '42183.7',
#    'begins_at': '2024-01-22T00:00:00Z',
#    'net_return': '0.0135',
#    'session': 'reg'},
#   {'adjusted_open_equity': '40356.57',
#    'adjusted_close_equity': '41049.21',
#    'open_equity': '40421.56',
#    'close_equity': '41114.2',
#    'open_market_value': '42151.67',
#    'close_market_value': '41659.36',
#    'begins_at': '2024-01-29T00:00:00Z',
#    'net_return': '0.0171',
#    'session': 'reg'},
#   {'adjusted_open_equity': '41738.321',
#    'adjusted_close_equity': '43850.92',
#    'open_equity': '41803.311',
#    'close_equity': '43910.91',
#    'open_market_value': '42348.471',
#    'close_market_value': '45357.95',
#    'begins_at': '2024-02-05T00:00:00Z',
#    'net_return': '0.0504',
#    'session': 'reg'},
#   {'adjusted_open_equity': '44052.235',
#    'adjusted_close_equity': '43276.019',
#    'open_equity': '44112.225',
#    'close_equity': '43336.009',
#    'open_market_value': '45559.265',
#    'close_market_value': '43669.069',
#    'begins_at': '2024-02-12T00:00:00Z',
#    'net_return': '-0.0176',
#    'session': 'reg'},
#   {'adjusted_open_equity': '42614.56',
#    'adjusted_close_equity': '44209.03',
#    'open_equity': '42674.55',
#    'close_equity': '44269.02',
#    'open_market_value': '43007.61',
#    'close_market_value': '45440.93',
#    'begins_at': '2024-02-19T00:00:00Z',
#    'net_return': '0.0374',
#    'session': 'reg'},
#   {'adjusted_open_equity': '44935.59',
#    'adjusted_close_equity': '46067.8',
#    'open_equity': '44995.58',
#    'close_equity': '46127.79',
#    'open_market_value': '46167.49',
#    'close_market_value': '46975.65',
#    'begins_at': '2024-02-26T00:00:00Z',
#    'net_return': '0.0252',
#    'session': 'reg'},
#   {'adjusted_open_equity': '47646.559',
#    'adjusted_close_equity': '55669.81',
#    'open_equity': '47706.549',
#    'close_equity': '55724.8',
#    'open_market_value': '48554.409',
#    'close_market_value': '42167.79',
#    'begins_at': '2024-03-04T00:00:00Z',
#    'net_return': '0.1681',
#    'session': 'reg'},
#   {'adjusted_open_equity': '55371.18',
#    'adjusted_close_equity': '55474.525',
#    'open_equity': '55426.17',
#    'close_equity': '55529.515',
#    'open_market_value': '41869.16',
#    'close_market_value': '52139.945',
#    'begins_at': '2024-03-11T00:00:00Z',
#    'net_return': '0.0019',
#    'session': 'reg'},
#   {'adjusted_open_equity': '55912.61',
#    'adjusted_close_equity': '56138.81',
#    'open_equity': '55967.6',
#    'close_equity': '56193.8',
#    'open_market_value': '52578.03',
#    'close_market_value': '57749.43',
#    'begins_at': '2024-03-18T00:00:00Z',
#    'net_return': '0.004',
#    'session': 'reg'},
#   {'adjusted_open_equity': '56304.655',
#    'adjusted_close_equity': '54976.955',
#    'open_equity': '56359.645',
#    'close_equity': '55031.945',
#    'open_market_value': '57915.275',
#    'close_market_value': '55776.315',
#    'begins_at': '2024-03-25T00:00:00Z',
#    'net_return': '-0.0236',
#    'session': 'reg'},
#   {'adjusted_open_equity': '55099.79',
#    'adjusted_close_equity': '54951.35',
#    'open_equity': '55154.78',
#    'close_equity': '55001.34',
#    'open_market_value': '55899.15',
#    'close_market_value': '55192.63',
#    'begins_at': '2024-04-01T00:00:00Z',
#    'net_return': '-0.0028',
#    'session': 'reg'},
#   {'adjusted_open_equity': '54214.72',
#    'adjusted_close_equity': '53455.84',
#    'open_equity': '54264.71',
#    'close_equity': '53505.83',
#    'open_market_value': '54456',
#    'close_market_value': '52075.21',
#    'begins_at': '2024-04-08T00:00:00Z',
#    'net_return': '-0.014',
#    'session': 'reg'},
#   {'adjusted_open_equity': '53515.07',
#    'adjusted_close_equity': '50904.06',
#    'open_equity': '53565.06',
#    'close_equity': '50954.05',
#    'open_market_value': '52134.44',
#    'close_market_value': '41533.38',
#    'begins_at': '2024-04-15T00:00:00Z',
#    'net_return': '-0.0487',
#    'session': 'reg'},
#   {'adjusted_open_equity': '51117.27',
#    'adjusted_close_equity': '52627.4',
#    'open_equity': '51167.26',
#    'close_equity': '52677.39',
#    'open_market_value': '41746.59',
#    'close_market_value': '54565.35',
#    'begins_at': '2024-04-22T00:00:00Z',
#    'net_return': '0.0295',
#    'session': 'reg'},
#   {'adjusted_open_equity': '51735.58',
#    'adjusted_close_equity': '52269.8',
#    'open_equity': '51785.57',
#    'close_equity': '52319.79',
#    'open_market_value': '53673.53',
#    'close_market_value': '48163.06',
#    'begins_at': '2024-04-29T00:00:00Z',
#    'net_return': '0.0103',
#    'session': 'reg'},
#   {'adjusted_open_equity': '52239.6905',
#    'adjusted_close_equity': '52791.8',
#    'open_equity': '52289.6805',
#    'close_equity': '52836.79',
#    'open_market_value': '48132.9505',
#    'close_market_value': '48981.58',
#    'begins_at': '2024-05-06T00:00:00Z',
#    'net_return': '0.0105',
#    'session': 'reg'},
#   {'adjusted_open_equity': '52817.64',
#    'adjusted_close_equity': '53749.4801',
#    'open_equity': '52862.63',
#    'close_equity': '53794.4701',
#    'open_market_value': '49007.42',
#    'close_market_value': '70927.6901',
#    'begins_at': '2024-05-13T00:00:00Z',
#    'net_return': '0.0176',
#    'session': 'reg'},
#   {'adjusted_open_equity': '55410.32',
#    'adjusted_close_equity': '71304.0629',
#    'open_equity': '55455.31',
#    'close_equity': '71349.0529',
#    'open_market_value': '72588.53',
#    'close_market_value': '69618.3129',
#    'begins_at': '2024-05-20T00:00:00Z',
#    'net_return': '0.2866',
#    'session': 'reg'},
#   {'adjusted_open_equity': '72945.37',
#    'adjusted_close_equity': '71884.665',
#    'open_equity': '72990.36',
#    'close_equity': '71929.655',
#    'open_market_value': '71259.62',
#    'close_market_value': '69133.315',
#    'begins_at': '2024-05-27T00:00:00Z',
#    'net_return': '-0.0145',
#    'session': 'reg'},
#   {'adjusted_open_equity': '73816.87',
#    'adjusted_close_equity': '65293.72',
#    'open_equity': '73861.86',
#    'close_equity': '65333.71',
#    'open_market_value': '71065.52',
#    'close_market_value': '73014.65',
#    'begins_at': '2024-06-03T00:00:00Z',
#    'net_return': '-0.1155',
#    'session': 'reg'},
#   {'adjusted_open_equity': '35279.21',
#    'adjusted_close_equity': '76262.245',
#    'open_equity': '35319.2',
#    'close_equity': '76302.235',
#    'open_market_value': '43000.14',
#    'close_market_value': '75697.145',
#    'begins_at': '2024-06-10T00:00:00Z',
#    'net_return': '1.1604',
#    'session': 'reg'},
#   {'adjusted_open_equity': '76643.1345',
#    'adjusted_close_equity': '73398.89',
#    'open_equity': '76683.1245',
#    'close_equity': '73438.88',
#    'open_market_value': '76078.0345',
#    'close_market_value': '80968.02',
#    'begins_at': '2024-06-17T00:00:00Z',
#    'net_return': '-0.0423',
#    'session': 'reg'},
#   {'adjusted_open_equity': '71031.7675',
#    'adjusted_close_equity': '71556.48',
#    'open_equity': '71071.7575',
#    'close_equity': '71596.47',
#    'open_market_value': '78600.8975',
#    'close_market_value': '76884.21',
#    'begins_at': '2024-06-24T00:00:00Z',
#    'net_return': '0.0074',
#    'session': 'reg'},
#   {'adjusted_open_equity': '71638.053',
#    'adjusted_close_equity': '72933.8',
#    'open_equity': '71678.043',
#    'close_equity': '72968.79',
#    'open_market_value': '76965.783',
#    'close_market_value': '79033.97',
#    'begins_at': '2024-07-01T00:00:00Z',
#    'net_return': '0.018',
#    'session': 'reg'},
#   {'adjusted_open_equity': '74097.28',
#    'adjusted_close_equity': '74514.436',
#    'open_equity': '74132.27',
#    'close_equity': '74549.426',
#    'open_market_value': '80197.45',
#    'close_market_value': '84697.486',
#    'begins_at': '2024-07-08T00:00:00Z',
#    'net_return': '0.0056',
#    'session': 'reg'},
#   {'adjusted_open_equity': '75510.355',
#    'adjusted_close_equity': '66215.3685',
#    'open_equity': '75545.345',
#    'close_equity': '66250.3585',
#    'open_market_value': '85693.405',
#    'close_market_value': '75350.5885',
#    'begins_at': '2024-07-15T00:00:00Z',
#    'net_return': '-0.123',
#    'session': 'reg'},
#   {'adjusted_open_equity': '65417.8465',
#    'adjusted_close_equity': '63573.891',
#    'open_equity': '65452.8365',
#    'close_equity': '63608.881',
#    'open_market_value': '74553.0665',
#    'close_market_value': '67604.321',
#    'begins_at': '2024-07-22T00:00:00Z',
#    'net_return': '-0.0282',
#    'session': 'reg'},
#   {'adjusted_open_equity': '63994.58',
#    'adjusted_close_equity': '57939.065',
#    'open_equity': '64029.57',
#    'close_equity': '57974.055',
#    'open_market_value': '68025.01',
#    'close_market_value': '79757.295',
#    'begins_at': '2024-07-29T00:00:00Z',
#    'net_return': '-0.0946',
#    'session': 'reg'},
#   {'adjusted_open_equity': '53397.0668',
#    'adjusted_close_equity': '54189.0143',
#    'open_equity': '53432.0568',
#    'close_equity': '54219.0043',
#    'open_market_value': '75215.2968',
#    'close_market_value': '57187.1243',
#    'begins_at': '2024-08-05T00:00:00Z',
#    'net_return': '0.0147',
#    'session': 'reg'},
#   {'adjusted_open_equity': '53173.135',
#    'adjusted_close_equity': '62782.0345',
#    'open_equity': '53203.125',
#    'close_equity': '62812.0245',
#    'open_market_value': '56171.245',
#    'close_market_value': '68926.1845',
#    'begins_at': '2024-08-12T00:00:00Z',
#    'net_return': '0.1806',
#    'session': 'reg'},
#   {'adjusted_open_equity': '61914.878',
#    'adjusted_close_equity': '66622.72',
#    'open_equity': '61944.868',
#    'close_equity': '66652.71',
#    'open_market_value': '68059.028',
#    'close_market_value': '74902.52',
#    'begins_at': '2024-08-19T00:00:00Z',
#    'net_return': '0.076',
#    'session': 'reg'},
#   {'adjusted_open_equity': '66762.575',
#    'adjusted_close_equity': '50289.63',
#    'open_equity': '66792.565',
#    'close_equity': '50319.62',
#    'open_market_value': '75042.375',
#    'close_market_value': '75488.96',
#    'begins_at': '2024-08-26T00:00:00Z',
#    'net_return': '-0.2466',
#    'session': 'reg'},
#   {'adjusted_open_equity': '43798.28',
#    'adjusted_close_equity': '38862.56',
#    'open_equity': '43828.27',
#    'close_equity': '38887.55',
#    'open_market_value': '68997.61',
#    'close_market_value': '54378.07',
#    'begins_at': '2024-09-02T00:00:00Z',
#    'net_return': '-0.1127',
#    'session': 'reg'},
#   {'adjusted_open_equity': '42149.17',
#    'adjusted_close_equity': '48155.69',
#    'open_equity': '42174.16',
#    'close_equity': '48180.68',
#    'open_market_value': '57664.68',
#    'close_market_value': '63893.26',
#    'begins_at': '2024-09-09T00:00:00Z',
#    'net_return': '0.1424',
#    'session': 'reg'},
#   {'adjusted_open_equity': '46209.48',
#    'adjusted_close_equity': '44725.45',
#    'open_equity': '46234.47',
#    'close_equity': '44750.44',
#    'open_market_value': '61947.05',
#    'close_market_value': '57456.29',
#    'begins_at': '2024-09-16T00:00:00Z',
#    'net_return': '-0.0321',
#    'session': 'reg'},
#   {'adjusted_open_equity': '44927.26',
#    'adjusted_close_equity': '46910.42',
#    'open_equity': '44952.25',
#    'close_equity': '46935.41',
#    'open_market_value': '57658.1',
#    'close_market_value': '61579.35',
#    'begins_at': '2024-09-23T00:00:00Z',
#    'net_return': '0.0441',
#    'session': 'reg'},
#   {'adjusted_open_equity': '45072.02',
#    'adjusted_close_equity': '48236.68',
#    'open_equity': '45097.01',
#    'close_equity': '48256.67',
#    'open_market_value': '59740.95',
#    'close_market_value': '61394.98',
#    'begins_at': '2024-09-30T00:00:00Z',
#    'net_return': '0.0701',
#    'session': 'reg'},
#   {'adjusted_open_equity': '48158.6098',
#    'adjusted_close_equity': '52970.1',
#    'open_equity': '48178.5998',
#    'close_equity': '52990.09',
#    'open_market_value': '61316.9098',
#    'close_market_value': '67883.49',
#    'begins_at': '2024-10-07T00:00:00Z',
#    'net_return': '0.0999',
#    'session': 'reg'},
#   {'adjusted_open_equity': '53907.24',
#    'adjusted_close_equity': '53950.38',
#    'open_equity': '53927.23',
#    'close_equity': '53970.37',
#    'open_market_value': '68820.63',
#    'close_market_value': '73737.42',
#    'begins_at': '2024-10-14T00:00:00Z',
#    'net_return': '0.0008',
#    'session': 'reg'},
#   {'adjusted_open_equity': '54004.17',
#    'adjusted_close_equity': '56277.4',
#    'open_equity': '54024.16',
#    'close_equity': '56297.39',
#    'open_market_value': '73791.21',
#    'close_market_value': '74306.51',
#    'begins_at': '2024-10-21T00:00:00Z',
#    'net_return': '0.0421',
#    'session': 'reg'},
#   {'adjusted_open_equity': '57764.26',
#    'adjusted_close_equity': '48915.85',
#    'open_equity': '57784.25',
#    'close_equity': '48930.84',
#    'open_market_value': '75793.37',
#    'close_market_value': '67895.66',
#    'begins_at': '2024-10-28T00:00:00Z',
#    'net_return': '-0.1532',
#    'session': 'reg'},
#   {'adjusted_open_equity': '50265.865',
#    'adjusted_close_equity': '59192.51',
#    'open_equity': '50280.855',
#    'close_equity': '59207.5',
#    'open_market_value': '69245.675',
#    'close_market_value': '66273',
#    'begins_at': '2024-11-04T00:00:00Z',
#    'net_return': '0.1775',
#    'session': 'reg'},
#   {'adjusted_open_equity': '60316.08',
#    'adjusted_close_equity': '58991.37',
#    'open_equity': '60331.07',
#    'close_equity': '59006.36',
#    'open_market_value': '67396.57',
#    'close_market_value': '50042.16',
#    'begins_at': '2024-11-11T00:00:00Z',
#    'net_return': '-0.022',
#    'session': 'reg'},
#   {'adjusted_open_equity': '58929.12',
#    'adjusted_close_equity': '60852.84',
#    'open_equity': '58944.11',
#    'close_equity': '60867.83',
#    'open_market_value': '49979.91',
#    'close_market_value': '53791.06',
#    'begins_at': '2024-11-18T00:00:00Z',
#    'net_return': '0.0326',
#    'session': 'reg'},
#   {'adjusted_open_equity': '62402.57',
#    'adjusted_close_equity': '60337.23',
#    'open_equity': '62417.56',
#    'close_equity': '60352.22',
#    'open_market_value': '55340.79',
#    'close_market_value': '53261.2',
#    'begins_at': '2024-11-25T00:00:00Z',
#    'net_return': '-0.0331',
#    'session': 'reg'},
#   {'adjusted_open_equity': '60632.73',
#    'adjusted_close_equity': '62310.1',
#    'open_equity': '60647.72',
#    'close_equity': '62320.09',
#    'open_market_value': '53556.7',
#    'close_market_value': '51187.46',
#    'begins_at': '2024-12-02T00:00:00Z',
#    'net_return': '0.0276',
#    'session': 'reg'},
#   {'adjusted_open_equity': '60812.54',
#    'adjusted_close_equity': '59828.1',
#    'open_equity': '60822.53',
#    'close_equity': '59838.09',
#    'open_market_value': '49689.9',
#    'close_market_value': '48702.86',
#    'begins_at': '2024-12-09T00:00:00Z',
#    'net_return': '-0.0162',
#    'session': 'reg'},
#   {'adjusted_open_equity': '59512.55',
#    'adjusted_close_equity': '58611.24',
#    'open_equity': '59522.54',
#    'close_equity': '58621.23',
#    'open_market_value': '48387.31',
#    'close_market_value': '49863.39',
#    'begins_at': '2024-12-16T00:00:00Z',
#    'net_return': '-0.0151',
#    'session': 'reg'},
#   {'adjusted_open_equity': '56289.14',
#    'adjusted_close_equity': '58328.91',
#    'open_equity': '56299.13',
#    'close_equity': '58338.9',
#    'open_market_value': '47541.29',
#    'close_market_value': '48929.58',
#    'begins_at': '2024-12-23T00:00:00Z',
#    'net_return': '0.0362',
#    'session': 'reg'},
#   {'adjusted_open_equity': '56564.885',
#    'adjusted_close_equity': '60198.97',
#    'open_equity': '56574.875',
#    'close_equity': '60203.96',
#    'open_market_value': '47165.555',
#    'close_market_value': '51767.67',
#    'begins_at': '2024-12-30T00:00:00Z',
#    'net_return': '0.0641',
#    'session': 'reg'},
#   {'adjusted_open_equity': '57582.94',
#    'adjusted_close_equity': '58507.84',
#    'open_equity': '57587.93',
#    'close_equity': '58512.84',
#    'open_market_value': '49151.64',
#    'close_market_value': '50076.46',
#    'begins_at': '2025-01-06T00:00:00Z',
#    'net_return': '0.0161',
#    'session': 'reg'},
#   {'adjusted_open_equity': '55848.41',
#    'adjusted_close_equity': '61489.85',
#    'open_equity': '55853.41',
#    'close_equity': '61494.85',
#    'open_market_value': '47417.03',
#    'close_market_value': '54536.51',
#    'begins_at': '2025-01-13T00:00:00Z',
#    'net_return': '0.101',
#    'session': 'reg'},
#   {'adjusted_open_equity': '61294.64',
#    'adjusted_close_equity': '63169.24',
#    'open_equity': '61299.64',
#    'close_equity': '63174.24',
#    'open_market_value': '54341.3',
#    'close_market_value': '68053.61',
#    'begins_at': '2025-01-20T00:00:00Z',
#    'net_return': '0.0306',
#    'session': 'reg'}],
#  'use_new_hp': True}

# %%
import pandas as pd

import matplotlib.pyplot as plt

# Convert the 'equity_historicals' list of dicts to a pandas DataFrame
historical_df = pd.DataFrame(historical_df['equity_historicals'])

# Convert 'begins_at' to datetime
historical_df['begins_at'] = pd.to_datetime(historical_df['begins_at'])

# Convert 'close_equity' field to numeric
historical_df['adjusted_close_equity'] = pd.to_numeric(historical_df['adjusted_close_equity'], errors='coerce')

# Sort by date
historical_df.sort_values(by='begins_at', inplace=True)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(historical_df['begins_at'], historical_df['adjusted_close_equity'], label='Portfolio Value')
plt.title('Robinhood Portfolio Value Over Time')
plt.xlabel('Date')
plt.ylabel('Equity ($)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import plotly.express as px

# Convert the 'equity_historicals' list of dicts to a pandas DataFrame
historical_df = pd.DataFrame(historical_df['equity_historicals'])

# Convert 'begins_at' to datetime
historical_df['begins_at'] = pd.to_datetime(historical_df['begins_at'])

# Convert 'close_equity' field to numeric
historical_df['adjusted_close_equity'] = pd.to_numeric(historical_df['adjusted_close_equity'], errors='coerce')

# Sort by date
historical_df.sort_values(by='begins_at', inplace=True)

# Plot the data using Plotly
fig = px.line(historical_df, x='begins_at', y='adjusted_close_equity', title='Robinhood Portfolio Value Over Time', labels={'begins_at': 'Date', 'adjusted_close_equity': 'Equity ($)'})
fig.update_layout(template='plotly_dark')

# Save the figure to an HTML file
#fig.write_html(file_output)

# Show the figure
fig.show()
# Out:
# <div>                            <div id="99587e5a-be8c-43d8-9400-393ef108cd84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99587e5a-be8c-43d8-9400-393ef108cd84")) {                    Plotly.newPlot(                        "99587e5a-be8c-43d8-9400-393ef108cd84",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eEquity ($)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-27T00:00:00+00:00","2020-02-03T00:00:00+00:00","2020-02-10T00:00:00+00:00","2020-02-17T00:00:00+00:00","2020-02-24T00:00:00+00:00","2020-03-02T00:00:00+00:00","2020-03-09T00:00:00+00:00","2020-03-16T00:00:00+00:00","2020-03-23T00:00:00+00:00","2020-03-30T00:00:00+00:00","2020-04-06T00:00:00+00:00","2020-04-13T00:00:00+00:00","2020-04-20T00:00:00+00:00","2020-04-27T00:00:00+00:00","2020-05-04T00:00:00+00:00","2020-05-11T00:00:00+00:00","2020-05-18T00:00:00+00:00","2020-05-25T00:00:00+00:00","2020-06-01T00:00:00+00:00","2020-06-08T00:00:00+00:00","2020-06-15T00:00:00+00:00","2020-06-22T00:00:00+00:00","2020-06-29T00:00:00+00:00","2020-07-06T00:00:00+00:00","2020-07-13T00:00:00+00:00","2020-07-20T00:00:00+00:00","2020-07-27T00:00:00+00:00","2020-08-03T00:00:00+00:00","2020-08-10T00:00:00+00:00","2020-08-17T00:00:00+00:00","2020-08-24T00:00:00+00:00","2020-08-31T00:00:00+00:00","2020-09-07T00:00:00+00:00","2020-09-14T00:00:00+00:00","
    # 'equity_historicals' is a list of daily records
    historicals = raw_data['equity_historicals']
    
    # Convert to DataFrame
    df = pd.DataFrame(historicals)
    
    # We can choose close_equity or open_equity. 
    # Let's pick 'close_equity' to represent daily portfolio value:
    df['timestamp'] = pd.to_datetime(df['begins_at'], utc=True).dt.tz_convert(None)
    df['equity'] = df['adjusted_close_equity'].astype(float)
    #df['adjusted_equity_previous_close'] = df['adjusted_equity_previous_close'].astype(float)
    
    # Keep only necessary columns
    df = df[['timestamp', 'equity']]
    
    # Sort by date ascending
    df = df.sort_values('timestamp').reset_index(drop=True)
    return df


def get_ticker_history(ticker, interval='day', span='5year'):
    """
    Fetch historical data for a given ticker (e.g. SPY, ARKK) using robin_stocks.
    Returns a pandas DataFrame with columns:
        ['timestamp', 'close_price']
    """
    raw_data = r.stocks.get_stock_historicals(
        ticker,
        interval=interval,
        span=span,
        bounds='regular'
    )
    
    # Convert to DataFrame
    df = pd.DataFrame(raw_data)
    
    # Example fields per record:
    #   {
    #       'begins_at': '2023-01-01T00:00:00Z',
    #       'close_price': '400.00',
    #       'open_price': '398.00',
    #       ...
    #   }
    
    df['timestamp'] = pd.to_datetime(df['begins_at'], utc=True).dt.tz_convert(None)
    df['close_price'] = df['close_price'].astype(float)
    
    # Keep only necessary columns
    df = df[['timestamp', 'close_price']]
    
    # Sort by date ascending
    df = df.sort_values('timestamp').reset_index(drop=True)
    return df


###############################################################################
#                          DATA PROCESSING HELPERS
###############################################################################
def filter_by_year(df, year):
    """
    Returns a slice of DataFrame for a specific calendar year.
    Expects a 'timestamp' column in df.
    """
    start = pd.Timestamp(f'{year}-01-01')
    end = pd.Timestamp(f'{year}-12-31 23:59:59')

    print('in filtering')
    print(df)
    print('post filtering')
    print(df[(df['timestamp'] >= start) & (df['timestamp'] <= end)])

    return df[(df['timestamp'] >= start) & (df['timestamp'] <= end)].copy()


def filter_by_date_range(df, start_date, end_date):
    """
    Returns data between start_date and end_date (inclusive).
    start_date/end_date can be strings or Timestamps.
    """
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)
    return df[(df['timestamp'] >= start) & (df['timestamp'] <= end)].copy()


def calculate_daily_returns(df, price_col='equity'):
    """
    Given a DataFrame with a date-based index or a 'timestamp' column
    and a price column (close_price, equity, etc.),
    compute daily returns = (price_today / price_yesterday) - 1.
    Returns a pd.Series of daily returns.
    """
    df = df.copy()
    df = df.sort_values('timestamp')
    df['daily_return'] = df[price_col].pct_change()
    return df['daily_return'].dropna()


###############################################################################
#                         PERFORMANCE METRICS CLASSES
###############################################################################
class PerformanceMetrics:
    """
    Class holding static methods to compute various performance metrics.
    """
    
    @staticmethod
    def annual_return(daily_returns):
        """
        Approximate annual return given daily returns.
        If daily_returns is for 1 full year, this yields that year's total return.
        """
        # Convert daily returns to total return factor
        cum_return_factor = (1 + daily_returns).prod()
        # For single-year data, this is simply (cum_return_factor - 1).
        # For partial year or multiple years, you may want to scale by # of trading days, etc.
        return cum_return_factor - 1.0
    
    @staticmethod
    def annualized_volatility(daily_returns, trading_days=252):
        """
        Compute annualized standard deviation of returns.
        """
        return daily_returns.std() * np.sqrt(trading_days)
    
    @staticmethod
    def sharpe_ratio(daily_returns, risk_free_rate=0.02, trading_days=252):
        """
        Sharpe Ratio = (Rp - Rf) / sigma,
        where Rf is risk-free rate, assumed annual,
        and we scale daily Rf to daily basis for convenience.
        """
        # Convert annual risk-free rate to daily
        daily_rf = (1 + risk_free_rate)**(1/trading_days) - 1
        
        excess_return_daily = daily_returns - daily_rf
        mean_excess = excess_return_daily.mean()
        std_excess = excess_return_daily.std()
        
        # annualize the mean_excess
        annual_excess = mean_excess * trading_days
        annual_std = std_excess * np.sqrt(trading_days)
        
        if annual_std == 0:
            return np.nan
        
        return annual_excess / annual_std
    
    @staticmethod
    def beta_alpha(portfolio_returns, market_returns, risk_free_rate=0.02, trading_days=252):
        """
        Compute Beta and Alpha using a simple linear regression with the CAPM model:
            (Rp - Rf) = alpha + beta * (Rm - Rf).
        
        Returns a tuple: (beta, alpha)
        - alpha is annualized
        - beta is slope of regression
        """
        # Convert to aligned series
        df = pd.DataFrame({
            'portfolio': portfolio_returns,
            'market': market_returns
        }).dropna()
        
        # If insufficient data, return None
        if len(df) < 2:
            return (np.nan, np.nan)
        
        daily_rf = (1 + risk_free_rate)**(1/trading_days) - 1
        
        df['excess_portfolio'] = df['portfolio'] - daily_rf
        df['excess_market'] = df['market'] - daily_rf
        
        # Perform linear regression: y = alpha + beta * x
        # Using np.polyfit on (excess_market, excess_portfolio)
        # slope = beta, intercept = alpha (but this alpha is daily alpha in decimal form)
        beta, alpha_daily = np.polyfit(df['excess_market'], df['excess_portfolio'], 1)
        
        # Annualize alpha (rough approximation by scaling daily alpha * 252)
        alpha_annual = alpha_daily * trading_days
        
        return beta, alpha_annual
    
    @staticmethod
    def max_drawdown(series):
        """
        Calculate the maximum drawdown of a time series of values (e.g. cumulative equity).
        The minimum value must occur after the peak value.
        """
        # Calculate the running maximum
        running_max = series.cummax()
        
        # Calculate the drawdown
        drawdown = (series - running_max) / running_max
        
        # The maximum drawdown is the minimum value of the drawdown series
        max_drawdown = drawdown.min()
        
        return max_drawdown


###############################################################################
#                 MAIN ANALYSIS FUNCTION (BY YEAR + CUMULATIVE)
###############################################################################
def analyze_portfolio_performance_old(
    start_year=2020,
    end_year=2024,
    interval='day',
    span='5year',
    risk_free_rate=0.02
):
    """
    1. Fetch portfolio data from Robinhood (5 years daily).
    2. Fetch SPY (S&P 500) and ARKK as benchmarks over the same period.
    3. For each year in [start_year, end_year], compute:
       - Annual Return
       - Sharpe Ratio
       - Beta, Alpha (vs. SPY)
       - Max Drawdown
    4. Also compute the same metrics for the entire [start_year-01-01, end_year-12-31] range.
    
    Returns a dict of results for each year, plus "Cumulative".
    """
    # --------------------- Fetch Data ---------------------
    ticker_histories = {
        'portfolio': get_portfolio_history(interval=interval, span=span),
        'ARKK': get_ticker_history('ARKK', interval=interval, span=span),
        'SPY': get_ticker_history('SPY', interval=interval, span=span),
        'DIA': get_ticker_history('DIA', interval=interval, span=span),
        'QQQ': get_ticker_history('QQQ', interval=interval, span=span),
        'IWM': get_ticker_history('IWM', interval=interval, span=span)  # Russell 2000 ETF
    }

    #df_portfolio = ticker_histories['portfolio']
    #df_spy = ticker_histories['SPY']
    #df_dia = ticker_histories['DIA']
    #df_qqq = ticker_histories['QQQ']
    #df_iwm = ticker_histories['IWM']

    
    # --------------------- Storage for results ---------------------
    yearly_results = {}
    
    # --------------------- Process each year individually ---------------------
    for year in range(start_year, end_year + 1):
        # Filter data for that year
        df_p_yr = filter_by_year(ticker_histories['portfolio'], year)
        df_spy_yr = filter_by_year(ticker_histories['SPY'], year)
        df_arkk_yr = filter_by_year(ticker_histories['ARKK'], year)
        
        # Calculate daily returns
        port_ret_yr = calculate_daily_returns(df_p_yr, 'equity')
        spy_ret_yr = calculate_daily_returns(df_spy_yr, 'close_price')
        arkk_ret_yr = calculate_daily_returns(df_arkk_yr, 'close_price')
        
        # If no data for a given year, skip
        if len(port_ret_yr) == 0:
            continue
        
        # Annual Return
        ann_ret = PerformanceMetrics.annual_return(port_ret_yr)
        
        # Sharpe Ratio
        sh_ratio = PerformanceMetrics.sharpe_ratio(
            port_ret_yr, 
            risk_free_rate=risk_free_rate
        )
        
        # Beta, Alpha (vs. SPY)
        beta_spy, alpha_spy = PerformanceMetrics.beta_alpha(
            port_ret_yr, 
            spy_ret_yr, 
            risk_free_rate=risk_free_rate
        )
        
        # Max Drawdown
        # We need the equity time-series to compute drawdown
        max_dd = np.nan
        if len(df_p_yr) > 0:
            max_dd = PerformanceMetrics.max_drawdown(df_p_yr['equity'])
        
        yearly_results[year] = {
            'Annual Return': ann_ret,
            'Sharpe Ratio': sh_ratio,
            'Beta (vs SPY)': beta_spy,
            'Alpha (vs SPY)': alpha_spy,
            'Max Drawdown': max_dd
        }
    
    # --------------------- Process Cumulative Period ---------------------
    start_date = f'{start_year}-01-01'
    end_date = f'{end_year}-12-31'
    
    df_p_cum = filter_by_date_range(ticker_histories['portfolio'], start_date, end_date)
    df_spy_cum = filter_by_date_range(ticker_histories['SPY'], start_date, end_date)
    df_arkk_cum = filter_by_date_range(ticker_histories['SPY'], start_date, end_date)
    
    port_ret_cum = calculate_daily_returns(df_p_cum, 'equity')
    spy_ret_cum = calculate_daily_returns(df_spy_cum, 'close_price')
    arkk_ret_cum = calculate_daily_returns(df_arkk_cum, 'close_price')
    
    # Annual return for entire period (approx)
    # This is a multi-year period, so you could do a geometric return approach:
    total_days = (df_p_cum['timestamp'].max() - df_p_cum['timestamp'].min()).days
    trading_days_per_year = 252
    
    if len(port_ret_cum) > 0:
        # Cumulative total return factor
        cum_factor = (1 + port_ret_cum).prod()
        # Approx # of years in this range
        years_in_period = total_days / 365.0
        
        # Geometric annualized return:
        ann_ret_cum = cum_factor**(1/years_in_period) - 1
        
        # Sharpe (annualized)
        sh_ratio_cum = PerformanceMetrics.sharpe_ratio(
            port_ret_cum, 
            risk_free_rate=risk_free_rate,
            trading_days=trading_days_per_year
        )
        
        # Beta, Alpha (vs SPY)
        beta_spy_cum, alpha_spy_cum = PerformanceMetrics.beta_alpha(
            port_ret_cum, 
            spy_ret_cum,
            risk_free_rate=risk_free_rate,
            trading_days=trading_days_per_year
        )
        
        # Max Drawdown
        max_dd_cum = PerformanceMetrics.max_drawdown(df_p_cum['equity'])
    else:
        ann_ret_cum = np.nan
        sh_ratio_cum = np.nan
        beta_spy_cum = np.nan
        alpha_spy_cum = np.nan
        max_dd_cum = np.nan
    
    yearly_results['Cumulative'] = {
        'Annual Return': ann_ret_cum,
        'Sharpe Ratio': sh_ratio_cum,
        'Beta (vs SPY)': beta_spy_cum,
        'Alpha (vs SPY)': alpha_spy_cum,
        'Max Drawdown': max_dd_cum
    }
    
    return yearly_results

# %%
def analyze_portfolio_performance(
    entity='portfolio',
    start_year=2020,
    end_year=2024,
    interval='day',
    span='5year',
    risk_free_rate=0.02
):
    """
    1. If entity == 'portfolio', fetch your personal portfolio data from Robinhood.
       Otherwise, fetch the specified ticker (e.g. 'SPY', 'AAPL', etc.)
    2. Fetch SPY (S&P 500) and ARKK as benchmarks over the same period.
    3. For each year in [start_year, end_year], compute:
       - Annual Return
       - Sharpe Ratio
       - Beta, Alpha (vs. SPY)
       - Max Drawdown
    4. Also compute the same metrics for the entire [start_year-01-01, end_year-12-31] range.
    
    Returns a dict of results for each year, plus "Cumulative".
    """
    # --------------------- Fetch Data ---------------------
    if entity == 'portfolio':
        data = get_portfolio_history(interval=interval, span=span)
    else:
        data = get_ticker_history(entity, interval=interval, span=span)
    
    ticker_histories = {
        'entity': data,
        'ARKK': get_ticker_history('ARKK', interval=interval, span=span),
        'SPY':  get_ticker_history('SPY', interval=interval, span=span),
        'DIA':  get_ticker_history('DIA', interval=interval, span=span),
        'QQQ':  get_ticker_history('QQQ', interval=interval, span=span),
        'IWM':  get_ticker_history('IWM', interval=interval, span=span)  # Russell 2000 ETF
    }

    # --------------------- Storage for results ---------------------
    yearly_results = {}
    
    # --------------------- Process each year individually ---------------------
    for year in range(start_year, end_year + 1):
        # Filter data for that year
        df_entity_yr = filter_by_year(ticker_histories['entity'], year)
        df_spy_yr    = filter_by_year(ticker_histories['SPY'], year)
        #df_arkk_yr   = filter_by_year(ticker_histories['ARKK'], year)
        
        # Calculate daily returns
        # Use 'equity' if it's the portfolio, else 'close_price'
        entity_col = 'equity' if entity == 'portfolio' else 'close_price'

        print('====================')
        print(f"Entity Column: {entity_col}")
        print(f"Entity Data: {df_entity_yr}")

        
        entity_ret_yr = calculate_daily_returns(df_entity_yr, entity_col)
        spy_ret_yr    = calculate_daily_returns(df_spy_yr, 'close_price')
        #arkk_ret_yr   = calculate_daily_returns(df_arkk_yr, 'close_price')
        
        # If no data for this year, skip
        if len(entity_ret_yr) == 0:
            continue
        
        # Annual Return
        ann_ret = PerformanceMetrics.annual_return(entity_ret_yr)
        
        # Sharpe Ratio
        sh_ratio = PerformanceMetrics.sharpe_ratio(
            entity_ret_yr, 
            risk_free_rate=risk_free_rate
        )
        
        # Beta, Alpha (vs. SPY)
        beta_spy, alpha_spy = PerformanceMetrics.beta_alpha(
            entity_ret_yr, 
            spy_ret_yr, 
            risk_free_rate=risk_free_rate
        )
        
        # Max Drawdown (need the actual price column to compute)
        max_dd = np.nan
        if len(df_entity_yr) > 0:
            max_dd = PerformanceMetrics.max_drawdown(df_entity_yr[entity_col])
        
        yearly_results[year] = {
            'Annual Return': ann_ret,
            'Sharpe Ratio': sh_ratio,
            'Beta (vs SPY)': beta_spy,
            'Alpha (vs SPY)': alpha_spy,
            'Max Drawdown': max_dd
        }
    
    # --------------------- Process Cumulative Period ---------------------
    start_date = f'{start_year}-01-01'
    end_date   = f'{end_year}-12-31'
    
    df_entity_cum = filter_by_date_range(ticker_histories['entity'], start_date, end_date)
    df_spy_cum    = filter_by_date_range(ticker_histories['SPY'], start_date, end_date)
    #df_arkk_cum   = filter_by_date_range(ticker_histories['ARKK'], start_date, end_date)

    entity_ret_cum = calculate_daily_returns(df_entity_cum, entity_col)
    spy_ret_cum    = calculate_daily_returns(df_spy_cum, 'close_price')
    #arkk_ret_cum   = calculate_daily_returns(df_arkk_cum, 'close_price')
    
    # Annual return for entire multi-year period
    total_days = (df_entity_cum['timestamp'].max() - df_entity_cum['timestamp'].min()).days
    trading_days_per_year = 252
    
    if len(entity_ret_cum) > 0:
        # Cumulative total return factor
        cum_factor = (1 + entity_ret_cum).prod()
        # Approx # of years in the range
        years_in_period = total_days / 365.0
        
        # Geometric annualized return:
        ann_ret_cum = cum_factor ** (1 / years_in_period) - 1
        
        # Sharpe (annualized)
        sh_ratio_cum = PerformanceMetrics.sharpe_ratio(
            entity_ret_cum, 
            risk_free_rate=risk_free_rate,
            trading_days=trading_days_per_year
        )
        
        # Beta, Alpha (vs. SPY)
        beta_spy_cum, alpha_spy_cum = PerformanceMetrics.beta_alpha(
            entity_ret_cum, 
            spy_ret_cum, 
            risk_free_rate=risk_free_rate,
            trading_days=trading_days_per_year
        )
        
        # Max Drawdown
        max_dd_cum = PerformanceMetrics.max_drawdown(df_entity_cum[entity_col])
        
        yearly_results['Cumulative'] = {
            'Annualized Return': ann_ret_cum,
            'Sharpe Ratio': sh_ratio_cum,
            'Beta (vs SPY)': beta_spy_cum,
            'Alpha (vs SPY)': alpha_spy_cum,
            'Max Drawdown': max_dd_cum
        }
    
    return yearly_results

# %%
indices = ['SPY', 'DIA', 'QQQ', 'VOO', 'IWM', 'BRK.B', 'VUG', 'VGT', 'ARKK']

results = {}

for index in indices:
    results[index] = analyze_portfolio_performance(
        entity=index,
        start_year=2020,
        end_year=2024,     # future-dated if you want the script to keep going
        interval='day',
        span='5year',
        risk_free_rate=0.02
    )

results['portfolio']  = analyze_portfolio_performance(
    entity='portfolio',
    start_year=2020,
    end_year=2024,     # future-dated if you want the script to keep going
    interval='day',
    span='5year',
    risk_free_rate=0.02
)
# Out:
# in filtering
#       timestamp  close_price
# 0    2020-01-27       323.50
# 1    2020-01-28       326.89
# 2    2020-01-29       326.62
# 3    2020-01-30       327.68
# 4    2020-01-31       321.73
# ...         ...          ...
# 1252 2025-01-17       597.58
# 1253 2025-01-21       603.05
# 1254 2025-01-22       606.44
# 1255 2025-01-23       609.75
# 1256 2025-01-24       607.97
#
# [1257 rows x 2 columns]
# post filtering
#      timestamp  close_price
# 0   2020-01-27       323.50
# 1   2020-01-28       326.89
# 2   2020-01-29       326.62
# 3   2020-01-30       327.68
# 4   2020-01-31       321.73
# ..         ...          ...
# 232 2020-12-24       369.00
# 233 2020-12-28       372.17
# 234 2020-12-29       371.46
# 235 2020-12-30       371.99
# 236 2020-12-31       373.88
#
# [237 rows x 2 columns]
# in filtering
#       timestamp  close_price
# 0    2020-01-27       323.50
# 1    2020-01-28       326.89
# 2    2020-01-29       326.62
# 3    2020-01-30       327.68
# 4    2020-01-31       321.73
# ...         ...          ...
# 1252 2025-01-17       597.58
# 1253 2025-01-21       603.05
# 1254 2025-01-22       606.44
# 1255 2025-01-23       609.75
# 1256 2025-01-24       607.97
#
# [1257 rows x 2 columns]
# post filtering
#      timestamp  close_price
#
# 1254 2025-01-22       606.44
# 1255 2025-01-23       609.75
# 1256 2025-01-24       607.97
#
# [1257 rows x 2 columns]
# post filtering
#       timestamp  close_price
# 990  2024-01-02       472.65
# 991  2024-01-03       468.79
# 992  2024-01-04       467.28
# 993  2024-01-05       467.92
# 994  2024-01-08       474.60
# ...         ...          ...
# 1237 2024-12-24       601.30
# 1238 2024-12-26       601.34
# 1239 2024-12-27       595.01
# 1240 2024-12-30       588.22
# 1241 2024-12-31       586.08
#
# [252 rows x 2 columns]
# ====================
# Entity Column: equity
# Entity Data:       timestamp    equity
# 990  2024-01-02  37178.67
# 991  2024-01-03  36752.60
# 992  2024-01-04  36944.42
# 993  2024-01-05  37287.99
# 994  2024-01-08  38398.07
# ...         ...       ...
# 1237 2024-12-24  59683.42
# 1238 2024-12-26  59570.19
# 1239 2024-12-27  58333.91
# 1240 2024-12-30  57951.73
# 1241 2024-12-31  57156.40
#
# [252 rows x 2 columns]

# %%
results['ARKK']  = analyze_portfolio_performance(
    entity='ARKK',
    start_year=2020,
    end_year=2024,     # future-dated if you want the script to keep going
    interval='day',
    span='5year',
    risk_free_rate=0.02
)

# %%
results
# Out:
# {'ARKK': {2020: {'Annual Return': 1.3577651515151512,
#    'Sharpe Ratio': 2.0314832371097733,
#    'Beta (vs SPY)': 1.147791953727379,
#    'Alpha (vs SPY)': 0.819375695276557,
#    'Max Drawdown': -0.4253768428027166},
#   2021: {'Annual Return': -0.241398668698372,
#    'Sharpe Ratio': -0.5495595480611094,
#    'Beta (vs SPY)': 1.6052546489196595,
#    'Alpha (vs SPY)': -0.6082113513982756,
#    'Max Drawdown': -0.41327117128624347},
#   2022: {'Annual Return': -0.6779049386534688,
#    'Sharpe Ratio': -1.3736165022105573,
#    'Beta (vs SPY)': 2.1225794415942048,
#    'Alpha (vs SPY)': -0.47666358534130226,
#    'Max Drawdown': -0.6944014846891432},
#   2023: {'Annual Return': 0.7193040052527915,
#    'Sharpe Ratio': 1.5117067201843188,
#    'Beta (vs SPY)': 2.207143929633718,
#    'Alpha (vs SPY)': 0.13918301574452263,
#    'Max Drawdown': -0.32675222112537017},
#   2024: {'Annual Return': 0.12415841584158427,
#    'Sharpe Ratio': 0.4515468754168515,
#    'Beta (vs SPY)': 2.1116863412418554,
#    'Alpha (vs SPY)': -0.26952034972820327,
#    'Max Drawdown': -0.23567002323780017},
#   'Cumulative': {'Annualized Return': 0.01478451036303463,
#    'Sharpe Ratio': 0.2310175660140972,
#    'Beta (vs SPY)': 1.596710493845395,
#    'Alpha (vs SPY)': -0.08024715149302035,
#    'Max Drawdown': -0.8107037935879423}},
#  'portfolio': {2020: {'Annual Return': 29053.417685213513,
#    'Sharpe Ratio': 1.037450336868576,
#    'Beta (vs SPY)': 191.80820576485587,
#    'Alpha (vs SPY)': 690.4015971590397,
#    'Max Drawdown': -0.08256424701340435},
#   2021: {'Annual Return': 1.0400102880690354,
#    'Sharpe Ratio': 1.5708767215454973,
#    'Beta (vs SPY)': 0.17361852326752808,
#    'Alpha (vs SPY)': 0.8136769109791537,
#    'Max Drawdown': -0.37391862374509566},
#   2022: {'Annual Return': -0.5527050501733735,
#    'Sharpe Ratio': -0.25941548214817683,
#    'Beta (vs SPY)': 0.8555389417295961,
#    'Alpha (vs SPY)': -0.07071550782411312,
#    'Max Drawdown': -0.7521547612130108},
#   2023: {'Annual Return': 0.6060616392945761,
#    'Sharpe Ratio': 1.4440316362752834,
#    'Beta (vs SPY)': 0.17944673794835156,
#    'Alpha (vs SPY)': 0.4857605330934503,
#    'Max Drawdown': -0.15240288732496193},
#   2024: {'Annual Return': 0.5347951839319773,
#    'Sharpe Ratio': 0.9682922520732098,
#    'Beta (vs SPY)': 2.7041079270031245,
#    'Alpha (vs SPY)': 0.055794759054349816,
#    'Max Drawdown': -0.5033016745369806},
#   'Cumulative': {'Annualized Return': 8.403189475180021,
#    'Sharpe Ratio': 0.4543159631615871,
#    'Beta (vs SPY)': 98.19167762045004,
#    'Alpha (vs SPY)': 126.77791898296981,
#    'Max Drawdown': -0.7678483177397086}}}

# %%
results_df
# Out:
#     Annual Return  Sharpe Ratio  Beta (vs SPY)  Alpha (vs SPY)  Max Drawdown  \
# 1        0.287887      1.860813       1.000000   -4.340226e-18     -0.054172
# 2       -0.199452     -0.878520       1.000000   -1.868828e-16     -0.253606
# 3        0.248122      1.615157       1.000000    4.480924e-16     -0.102907
# 4        0.239987      1.630958       1.000000   -3.326803e-16     -0.083943
# 7        0.201773      1.395546       0.847758   -3.345186e-02     -0.065492
# 8       -0.093935     -0.502757       0.784313    6.843108e-02     -0.219018
# 9        0.137824      1.021160       0.781785   -4.924964e-02     -0.089865
# 10       0.128378      0.951557       0.741146   -4.335065e-02     -0.060981
# 13       0.286250      1.371475       1.211704   -4.466265e-02     -0.108515
# 14      -0.337084     -1.187605       1.269280   -1.102480e-01     -0.352470
# 15       0.548397      2.454953       1.235969    1.753422e-01     -0.109089
# 16       0.269853      1.316335       1.355045   -4.026711e-02     -0.135577
# 19       0.287703      1.892215       0.978699    4.718075e-03     -0.054040
# 20      -0.200137     -0.892808       0.987335   -4.135586e-03     -0.254092
# 21       0.248036      1.628749       0.986550    2.635377e-03     -0.103071
# 22       0.241469      1.627373       1.003550    6.129817e-04     -0.084517
# 25       0.149612      0.656220       1.250582   -1.593802e-01     -0.125495
# 26      -0.226167     -0.847678       1.071649   -9.000039e-03     -0.272590
# 27       0.157497      0.736205       1.221372   -1.120541e-01     -0.183685
# 28       0.107458      0.501001       1.209188   -1.425081e-01     -0.100712
# 31       0.308820      1.705804       0.730433    8.492211e-02     -0.067893
# 32       0.026962      0.143272       0.747984    1.926547e-01     -0.265790
# 33       0.150850      0.963818       0.714411   -2.064414e-02     -0.104648
# 34       0.250566      1.483766       0.523944    1.083246e-01     -0.075809
# 37       0.285348      1.440628       1.173225   -3.787933e-02     -0.095761
# 38      -0.340401     -1.190572       1.287065   -1.106520e-01     -0.354855
# 39       0.469118      2.263404       1.203146    1.275064e-01     -0.108893
# 40       0.343151      1.678798       1.314023    2.349332e-02     -0.129765
# 43       0.316921      1.397665       1.321412   -4.466814e-02     -0.108247
# 44      -0.308636     -0.983517       1.333837   -4.834011e-02     -0.348831
# 45       0.529951      2.278469       1.268234    1.579956e-01     -0.130598
# 46       0.319358      1.311294       1.568993   -3.852537e-02     -0.152295
# 49      -0.241399     -0.549560       1.605255   -6.082114e-01     -0.413271
# 50      -0.677905     -1.373617       2.122579   -4.766636e-01     -0.694401
# 51       0.719304      1.511707       2.207144    1.391830e-01     -0.326752
# 52       0.124158      0.451547       2.111686   -2.695203e-01     -0.235670
# 55       1.040010      1.570877       0.173619    8.136769e-01     -0.373919
# 56      -0.552705     -0.259415       0.855539   -7.071551e-02     -0.752155
# 57       0.606062      1.444032       0.179447    4.857605e-01     -0.152403
# 58       0.534795      0.968292       2.704108    5.579476e-02     -0.503302
#
#     Year     Entity  Annualized Return
# 1   2021        SPY                NaN
# 2   2022        SPY                NaN
# 3   2023        SPY                NaN
# 4   2024        SPY                NaN
# 7   2021        DIA                NaN
# 8   2022        DIA                NaN
# 9   2023        DIA                NaN
# 10  2024        DIA                NaN
# 13  2021        QQQ                NaN
# 14  2022        QQQ                NaN
# 15  2023        QQQ                NaN
# 16  2024        QQQ                NaN
# 19  2021        VOO                NaN
# 20  2022        VOO                NaN
# 21  2023        VOO                NaN
# 22  2024        VOO                NaN
# 25  2021        IWM                NaN
# 26  2022        IWM                NaN
# 27  2023        IWM                NaN
# 28  2024        IWM                NaN
# 31  2021      BRK.B                NaN
# 32  2022      BRK.B                NaN
# 33  2023      BRK.B                NaN
# 34  2024      BRK.B                NaN
# 37  2021        VUG                NaN
# 38  2022        VUG                NaN
# 39  2023        VUG                NaN
# 40  2024        VUG                NaN
# 43  2021        VGT                NaN
# 44  2022        VGT                NaN
# 45  2023        VGT                NaN
# 46  2024        VGT                NaN
# 49  2021       ARKK                NaN
# 50  2022       ARKK                NaN
# 51  2023       ARKK                NaN
# 52  2024       ARKK                NaN
# 55  2021  portfolio                NaN
# 56  2022  portfolio                NaN
# 57  2023  portfolio                NaN
# 58  2024  portfolio                NaN

# %%
import pandas as pd

import plotly.express as px

# Flatten the nested results dictionary
flattened_results = []
for entity, yearly_data in results.items():
    for year, metrics in yearly_data.items():
        metrics['Year'] = year
        metrics['Entity'] = entity
        flattened_results.append(metrics)

# Convert the flattened list of dictionaries into a DataFrame
results_df = pd.DataFrame(flattened_results)

# %%
results_df
# Out:
#     Annual Return  Sharpe Ratio  Beta (vs SPY)  Alpha (vs SPY)  Max Drawdown  \
# 0        0.155734      0.563602       1.000000   -7.834013e-17     -0.341047
# 1        0.287887      1.860813       1.000000   -4.340226e-18     -0.054172
# 2       -0.199452     -0.878520       1.000000   -1.868828e-16     -0.253606
# 3        0.248122      1.615157       1.000000    4.480924e-16     -0.102907
# 4        0.239987      1.630958       1.000000   -3.326803e-16     -0.083943
# 5             NaN      0.582697       1.000000   -4.402751e-16     -0.341047
# 6        0.071594      0.333039       1.071988   -8.329418e-02     -0.370587
# 7        0.201773      1.395546       0.847758   -3.345186e-02     -0.065492
# 8       -0.093935     -0.502757       0.784313    6.843108e-02     -0.219018
# 55       1.520189      1.483078       0.421376    1.032138e+00     -0.166333
# 56      -0.150887     -0.388666       0.648879    9.726629e-03     -0.352498
# 57       0.610784      1.448655       0.180237    4.889763e-01     -0.152708
# 58       0.537344      0.970765       2.705564    5.737163e-02     -0.503367
# 59            NaN      0.966931       0.505230    4.365842e-01     -0.503367
#
#           Year     Entity  Annualized Return
# 0         2020        SPY                NaN
# 1         2021        SPY                NaN
# 2         2022        SPY                NaN
# 3         2023        SPY                NaN
# 4         2024        SPY                NaN
# 5   Cumulative        SPY           0.128063
# 6         2020        DIA                NaN
# 7         2021        DIA                NaN
# 8         2022        DIA                NaN
# 9         2023        DIA                NaN
# 10        2024        DIA                NaN
# 11  Cumulative        DIA           0.084384
# 12        2020        QQQ                NaN
# 13        2021        QQQ                NaN
# 14        2022        QQQ                NaN
# 15        2023        QQQ                NaN
# 16        2024        QQQ                NaN
# 17  Cumulative        QQQ           0.188556
# 18        2020        VOO                NaN
# 19        2021        VOO                NaN
# 20        2022        VOO                NaN
# 21        2023        VOO                NaN
# 22        2024        VOO                NaN
# 23  Cumulative        VOO           0.128200
# 24        2020        IWM                NaN
# 25        2021        IWM                NaN
# 26        2022        IWM                NaN
# 27        2023        IWM                NaN
# 28        2024        IWM                NaN
# 29  Cumulative        IWM           0.062960
# 30        2020      BRK.B                NaN
# 31        2021      BRK.B                NaN
# 32        2022      BRK.B                NaN
# 33        2023      BRK.B                NaN
# 34        2024      BRK.B                NaN
# 35  Cumulative      BRK.B           0.155275
# 36        2020        VUG                NaN
# 37        2021        VUG                NaN
# 38        2022        VUG                NaN
# 39        2023        VUG                NaN
# 40        2024        VUG                NaN
# 41  Cumulative        VUG           0.172156
# 42        2020        VGT                NaN
# 43        2021        VGT                NaN
# 44        2022        VGT                NaN
# 45        2023        VGT                NaN
# 46        2024        VGT                NaN
# 47  Cumulative        VGT           0.199019
# 48        2020       ARKK                NaN
# 49        2021       ARKK                NaN
# 50        2022       ARKK                NaN
# 51        2023       ARKK                NaN
# 52        2024       ARKK                NaN
# 53  Cumulative       ARKK           0.018552
# 54        2020  portfolio                NaN
# 55        2021  portfolio                NaN
# 56        2022  portfolio                NaN
# 57        2023  portfolio                NaN
# 58        2024  portfolio                NaN
# 59  Cumulative  portfolio           0.489869

# %%
results_df['Beta (vs SPY)'].max()
# Out:
# 2.7055642813823773

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

file_output = '../plots/reports/robinhood_portfolio_performance.html'

# Filter ranges
results_cum = results_df[results_df['Year'] == 'Cumulative']
results_df = results_df[results_df['Year'] != 2020]
results_df = results_df[results_df['Year'] != 'Cumulative']

selected_entities = ['portfolio', 'SPY', 'DIA', 'QQQ', 'VOO', 'BRK.B', 'ARKK']

# Define a color map for entities
color_map = {
    'portfolio': 'blue',
    'SPY': 'red',
    'DIA': 'green',
    'QQQ': 'purple',
    'VOO': 'orange',
    'BRK.B': 'brown',
    'ARKK': 'pink'
}

# Create a subplot figure with 5 rows and 1 column
fig = make_subplots(rows=5, cols=1, subplot_titles=(
    'Annual Return Over Time',
    'Sharpe Ratio Over Time',
    'Beta (vs SPY) Over Time',
    'Alpha (vs SPY) Over Time',
    'Max Drawdown Over Time'
))

# Annual Return plot
for entity in selected_entities:
    entity_data = results_df[results_df['Entity'] == entity]
    fig.add_trace(go.Bar(x=entity_data['Year'], y=entity_data['Annual Return'], name=f'{entity} Annual Return', marker_color=color_map[entity], text=entity_data['Entity'], textposition='auto'), row=1, col=1)

# Sharpe Ratio plot
for entity in selected_entities:
    entity_data = results_df[results_df['Entity'] == entity]
    fig.add_trace(go.Bar(x=entity_data['Year'], y=entity_data['Sharpe Ratio'], name=f'{entity} Sharpe Ratio', marker_color=color_map[entity], text=entity_data['Entity'], textposition='auto'), row=2, col=1)

# Beta (vs SPY) plot
for entity in selected_entities:
    entity_data = results_df[results_df['Entity'] == entity]
    fig.add_trace(go.Bar(x=entity_data['Year'], y=entity_data['Beta (vs SPY)'], name=f'{entity} Beta (vs SPY)', marker_color=color_map[entity], text=entity_data['Entity'], textposition='auto'), row=3, col=1)

# Alpha (vs SPY) plot
for entity in selected_entities:
    entity_data = results_df[results_df['Entity'] == entity]
    fig.add_trace(go.Bar(x=entity_data['Year'], y=entity_data['Alpha (vs SPY)'], name=f'{entity} Alpha (vs SPY)', marker_color=color_map[entity], text=entity_data['Entity'], textposition='auto'), row=4, col=1)

# Max Drawdown plot
for entity in selected_entities:
    entity_data = results_df[results_df['Entity'] == entity]
    fig.add_trace(go.Bar(x=entity_data['Year'], y=entity_data['Max Drawdown'], name=f'{entity} Max Drawdown', marker_color=color_map[entity], text=entity_data['Entity'], textposition='auto'), row=5, col=1)

# Update layout
fig.update_layout(height=1500, width=1000, title_text="Omair's Portfolio Performance Metrics Over Time", barmode='group')

# Save the figure to an HTML file
fig.write_html(file_output)

# Show the figure
fig.show()
# Out:
# <div>                            <div id="24fb7ae9-ccdb-41cc-bf36-b94e8dc42c70" class="plotly-graph-div" style="height:1500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24fb7ae9-ccdb-41cc-bf36-b94e8dc42c70")) {                    Plotly.newPlot(                        "24fb7ae9-ccdb-41cc-bf36-b94e8dc42c70",                        [{"marker":{"color":"blue"},"name":"portfolio Annual Return","text":["portfolio","portfolio","portfolio","portfolio"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[1.520188730569744,-0.15088728635574622,0.6107838294575498,0.5373438587232924],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"red"},"name":"SPY Annual Return","text":["SPY","SPY","SPY","SPY"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[0.28788741560237563,-0.1994515501036186,0.24812247255921327,0.2399873056172639],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"green"},"name":"DIA Annual Return","text":["DIA","DIA","DIA","DIA"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[0.20177295580841448,-0.09393458761758988,0.13782380291045282,0.12837784083375126],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"purple"},"name":"QQQ Annual Return","text":["QQQ","QQQ","QQQ","QQQ"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[0.2862500404125352,-0.3370842461661028,0.5483968542044757,0.26985270374326076],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"orange"},"name":"VOO Annual Return","text":["VOO","VOO","VOO","VOO"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[0.2877031531132952,-0.20013659647125792,0.24803565816166095,0.24146909057395027],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"brown"},"name":"BRK.B Annual Return","text":["BRK.B","BRK.B","BRK.B","BRK.B"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[0.3088203107901073,0.026962332524352872,0.15085024684585946,0.25056557965016757],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"pink"},"name":"ARKK Annual Return","text":["ARKK","ARKK","ARKK","ARKK"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[-0.241398668698372,-0.6779049386534688,0.7193040052527915,0.12415841584158427],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"blue"},"name":"portfolio Sharpe Ratio","text":["portfolio","portfolio","portfolio","portfolio"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[1.4830779743002416,-0.38866623172130804,1.4486548767337977,0.9707652493045461],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"red"},"name":"SPY Sharpe Ratio","text":["SPY","SPY","SPY","SPY"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[1.8608128776306538,-0.8785197252781508,1.6151572926478222,1.63095762371058],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"green"},"name":"DIA Sharpe Ratio","text":["DIA","DIA","DIA","DIA"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[1.3955458895915223,-0.5027568513174662,1.0211598612951376,0.9515569365391683],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"purple"},"name":"QQQ Sharpe Ratio","text":["QQQ","QQQ","QQQ","QQQ"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[1.3714747178332949,-1.1876050951683976,2.4549534229050147,1.3163349749081974],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"orange"},"name":"VOO Sharpe Ratio","text":["VOO","VOO","VOO","VOO"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[1.8922152133198251,-0.8928083447765891,1.6287491094258526,1.627372945745504],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"brown"},"name":"BRK.B Sharpe Ratio","text":["BRK.B","BRK.B","BRK.B","BRK.B"],"textposition":"auto","x":[2021,2022,2023,2024],"y":[1.7058041948068112,0.14327230600029106,0.9638178727175372,1.4837662636422275],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"pink" ...

# %%
results_cum[results_cum['Year']=='Cumulative'].sort_values('Annualized Return', ascending=False)
# Out:
#     Annual Return  Sharpe Ratio  Beta (vs SPY)  Alpha (vs SPY)  Max Drawdown  \
# 59            NaN      0.966931       0.505230    4.365842e-01     -0.503367
# 47            NaN      0.716984       1.234583    4.926723e-02     -0.354559
# 17            NaN      0.723930       1.128883    4.720055e-02     -0.356172
# 41            NaN      0.676610       1.136794    3.127920e-02     -0.359966
# 35            NaN      0.682367       0.809142    4.852344e-02     -0.293890
# 23            NaN      0.580076       1.005733   -1.963100e-04     -0.343014
# 5             NaN      0.582697       1.000000   -4.402751e-16     -0.341047
# 11            NaN      0.399472       0.930546   -3.176953e-02     -0.370587
# 29            NaN      0.288773       1.121056   -5.886237e-02     -0.408210
# 53            NaN      0.238748       1.597309   -8.193893e-02     -0.810704
#
#           Year     Entity  Annualized Return
# 59  Cumulative  portfolio           0.489869
# 47  Cumulative        VGT           0.199019
# 17  Cumulative        QQQ           0.188556
# 41  Cumulative        VUG           0.172156
# 35  Cumulative      BRK.B           0.155275
# 23  Cumulative        VOO           0.128200
# 5   Cumulative        SPY           0.128063
# 11  Cumulative        DIA           0.084384
# 29  Cumulative        IWM           0.062960
# 53  Cumulative       ARKK           0.018552
